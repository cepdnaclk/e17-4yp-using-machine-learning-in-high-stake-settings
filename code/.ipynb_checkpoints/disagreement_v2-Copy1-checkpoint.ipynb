# %% [markdown]
# Load testfiles

# %%
# Import libraries
# !pip install lime
# os.chdir("../")
import os
import pandas as pd
import pickle
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import random
# import lime
from lime import lime_tabular
import shap

import json
from typing import Union
from datetime import datetime as dt
import numpy as np
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
PROCESSED_DATA = "/storage/scratch/e17-fyp-xai/projects/e17-4yp-using-machine-learning-in-high-stake-settings/code/processed_data/processed_final_data_latest.csv"

# %%
raw_data = pd.read_csv(PROCESSED_DATA)

# %%
raw_data.head()
# Out:
#    Unnamed: 0                        Project ID Project Posted Date  \
# 0           0  699d6d657a8cd2a83ba09ee8bbb4bacf          2015-08-23
# 1           2  9712349367ff50b9eab00445594a25cd          2016-04-02
# 2           4  baa270ad21f432dcf6943cfe0cf51313          2016-09-16
# 3           6  cf54d3a016f6f715f5cea46f0aba15e0          2015-11-08
# 4           7  05970d5f4232634dee18e8e92a19c206          2014-08-01
#
#   Project Type  Project Posted Month    Project Subject Category Tree  \
# 0  Teacher-Led                     8  Applied Learning, Special Needs
# 1  Teacher-Led                     4              Literacy & Language
# 2  Teacher-Led                     9                  Health & Sports
# 3  Teacher-Led                    11              Literacy & Language
# 4  Teacher-Led                     8                   Math & Science
#
#    Project Cost Project Subject Subcategory Tree Project Grade Level Category  \
# 0        511.29             Other, Special Needs                Grades PreK-2
# 1        189.58                    ESL, Literacy                Grades PreK-2
# 2        826.89                Health & Wellness                   Grades 6-8
# 3        653.28                         Literacy                Grades PreK-2
# 4        690.67                      Mathematics                   Grades 3-5
#
#   Project Resource Category  ... Label  Teacher Success Rate  \
# 0                     Other  ...     0                   0.0
# 1                     Books  ...     0                   0.0
# 2                  Supplies  ...     0                   0.0
# 3                     Books  ...     0                   0.0
# 4                  Supplies  ...     1                   0.0
#
#   Teacher Success Rate Imputed School City Success Rate  \
# 0                            1                 0.726070
# 1                            1                 0.584906
# 2                            1                 0.621951
# 3                            1                 0.600000
# 4                            1                 0.750000
#
#    School City Success Rate Imputed  School Success Rate  \
# 0                                 0               1.0000
# 1                                 0               0.3125
# 2                                 0               0.0000
# 3                                 0               0.0000
# 4                                 0               0.0000
#
#    School Success Rate Imputed  School County Success Rate  \
# 0                            0                    0.753059
# 1                            0                    0.676056
# 2                            0                    0.658787
# 3                            1                    0.694737
# 4                            1                    0.750000
#
#    School County Success Rate Imputed  Project Count in State
# 0                                   0                    3584
# 1                                   0                    7070
# 2                                   0                    8875
# 3                                   0                     876
# 4                                   0                     627
#
# [5 rows x 25 columns]

# %%
raw_data[raw_data["Project ID"] == "cdc83b2eb031d999c123535bf09d24a0" ]
# Out:
#         Unnamed: 0                        Project ID Project Posted Date  \
# 314336      603375  cdc83b2eb031d999c123535bf09d24a0          2016-11-14
#
#        Project Type  Project Posted Month Project Subject Category Tree  \
# 314336  Teacher-Led                    11                Math & Science
#
#         Project Cost Project Subject Subcategory Tree  \
# 314336       3334.51                      Mathematics
#
#        Project Grade Level Category Project Resource Category  ... Label  \
# 314336                Grades PreK-2                Technology  ...     1
#
#         Teacher Success Rate Teacher Success Rate Imputed  \
# 314336                   0.4                            0
#
#        School City Success Rate  School City Success Rate Imputed  \
# 314336                 0.388889                                 0
#
#         School Success Rate  School Success Rate Imputed  \
# 314336             0.285714                            0
#
#         School County Success Rate  School County Success Rate Imputed  \
# 314336                    0.614035                                   0
#
#         Project Count in State
# 314336                     682
#
# [1 rows x 25 columns]

# %%
# !ls
# Out:
#  compactor		 Feature_Engineering.ipynb   model_parameters
#  config.py		 Feature_Engineering.py      __pycache__
#  data_processer.ipynb	 feature_engineer.py	     README.md
#  data_processor.py	'Global Vs lime.ipynb'	     requirements.txt
#  disagreement.ipynb	 helper.py		     run_explanations.py
#  disagreement.py	 kernelshap_explainer.py     Sanity_checks.ipynb
#  disagreement_v2.ipynb	 lime_explainer.py	     temporal_features.py
#  eda.py			 main.py		     test.png
#  environment.yml	 model_outputs		     treeshap_explainer.py

# %%
os.chdir("/storage/scratch/e17-fyp-xai/projects/thanujan/e17-4yp-using-machine-learning-in-high-stake-settings/code")
import os
import feature_engineer as fe 
import data_processor as dp
import config
from helper import (
    save_model,
    load_model,
    create_dirs,
    create_classification_models,
    create_logistic_regression_parameters,
    create_random_forest_parameters,
    create_xgb_classifier_parameters,
    log_intermediate_output_to_file,
    filter_dataset_by_date)
import temporal_features as tmpf
import config

# %%
data = dp.set_data_types_to_datetime(raw_data, ["Project Posted Date"])
data = filter_dataset_by_date(data)
data_1 = dp.encode_data(data, config.CATEGORICAL_COLS)
data_folds = fe.split_data_folds(data_1)
# Out:
# -----
# train    2016-01-07 - 2016-07-05
# test     2016-11-02 - 2016-12-02
# (238834, 578)
# (92313, 577)
# (92313, 576)
# (92313, 1)
# (32134, 578)
# (20079, 577)
# (20079, 576)
# (20079, 576)
# Training set shape =  (92313, 576)
# Testing set shape =  (20079, 576)
# -----
# -----
# train    2015-09-09 - 2016-03-07
# test     2016-07-05 - 2016-08-04
# (314310, 578)
# (105920, 577)
# (105920, 576)
# (105920, 1)
# (146069, 578)
# (18750, 577)
# (18750, 576)
# (18750, 576)
# Training set shape =  (105920, 576)
# Testing set shape =  (18750, 576)
# -----
# -----
# train    2015-05-12 - 2015-11-08
# test     2016-03-07 - 2016-04-06
# (370969, 578)
# (99939, 577)
# (99939, 576)
# (99939, 1)
# (207731, 578)
# (23932, 577)
# (23932, 576)
# (23932, 576)
# Training set shape =  (99939, 576)
# Testing set shape =  (23932, 576)
# -----
# -----
# train    2015-01-12 - 2015-07-11
# test     2015-11-08 - 2015-12-08
# (416306, 578)
# (61637, 577)
# (61637, 576)
# (61637, 1)
# (270016, 578)
# (18400, 577)
# (18400, 576)
# (18400, 576)
# Training set shape =  (61637, 576)
# Testing set shape =  (18400, 576)
# -----
# -----
# train    2014-09-14 - 2015-03-13
# test     2015-07-11 - 2015-08-10
# (471772, 578)
# (80838, 577)
# (80838, 576)
# (80838, 1)
# (354423, 578)
# (12232, 577)
# (12232, 576)
# (12232, 576)
# Training set shape =  (80838, 576)
# Testing set shape =  (12232, 576)
# -----
# -----
# train    2014-05-17 - 2014-11-13
# test     2015-03-13 - 2015-04-12
# (535150, 578)
# (100159, 577)
# (100159, 576)
# (100159, 1)
# (390393, 578)
# (10499, 577)
# (10499, 576)
# (10499, 576)
# Training set shape =  (100159, 576)
# Testing set shape =  (10499, 576)
# -----

# %%
# # for data in :
# #     if data=="cdc83b2eb031d999c123535bf09d24a0":
# #         print(data)

# data_folds[0]["x_test"][data_folds[0]["x_test"]["Project ID"] == "cdc83b2eb031d999c123535bf09d24a0"].columns ==

# %%
from disagreement import Disagreement
import json

# %%
# !ls
# Out:
#  compactor		 Feature_Engineering.ipynb   model_parameters
#  config.py		 Feature_Engineering.py      __pycache__
#  data_processer.ipynb	 feature_engineer.py	     README.md
#  data_processor.py	'Global Vs lime.ipynb'	     requirements.txt
#  disagreement.ipynb	 helper.py		     run_explanations.py
#  disagreement.py	 kernelshap_explainer.py     Sanity_checks.ipynb
#  disagreement_v2.ipynb	 lime_explainer.py	     temporal_features.py
#  eda.py			 main.py		     test.png
#  environment.yml	 model_outputs		     treeshap_explainer.py

# %%
explanations = json.load(open("/storage/scratch/e17-fyp-xai/projects/e17-4yp-using-machine-learning-in-high-stake-settings/code/model_outputs_5/xai_results/all_exp.json"))

# %%
# !ls /storage/scratch/e17-fyp-xai/projects/e17-4yp-using-machine-learning-in-high-stake-settings/
# Out:
#  code
#  code_base_II
#  docs
#  Documents
#  EDA_Projects.ipynb
#  fold_data
# 'Model explaination for top 50 and bottom 50 -- lime.ipynb'
#  nohup.out
#  output_Xai_latest.out
#  output_Xai_latest_sep_18.out
#  output_Xai_latest_sep_19.out
#  output_Xai.out
# 'ratio_of averages.csv'
#  README.md
#  Sanity_checks_2.ipynb
#  Sanity_checks.ipynb
#  thanujan.py
#  Untitled.ipynb
#  XAI_Pipeline.ipynb
#  XAI_Pipeline_latest.ipynb
#  XAI_Pipeline_new.ipynb
#  XAI_Pipeline_new_latest_out.ipynb
#  XAI_Pipeline_new_out.ipynb
#  XAI_Pipeline_result_16_sep.ipynb
#  XAI_Pipeline_sep_18.ipynb
#  XAI_Pipeline_sep_19.ipynb
#  XAI_Pipeline_sep_21_top_500_bottom_500.ipynb
#  XAI_Pipeline_sep_22_top_500_bottom_500_2.ipynb
#  XAI_Pipeline_sep_22_top_500_bottom_500.ipynb
#  XAI_Pipeline_sep_23_latest.ipynb
#  XAI_Pipeline_sep_23_latest_output.ipynb
#  XAI_Pipeline_test.ipynb
#  xai_results
#  xai_test_results

# %%
explanations.keys()
# Out:
# dict_keys(['fold5', 'fold4', 'fold3', 'fold2', 'fold1', 'fold0'])

# %%
explanations["fold0"].keys()
# Out:
# dict_keys(['lime', 'treeshap'])

# %%
explanations["fold0"]["lime"].keys()
# Out:
# dict_keys(['top', 'bottom'])

# %% [markdown]
# Projects in the lime top explanations

# %%
list(explanations["fold0"]["lime"]["top"].keys())[:10]
# Out:
# ['cdc83b2eb031d999c123535bf09d24a0',
#  '203c08ca3b1e42a9ba07c93eac4c20cc',
#  'd1fb6298685f8afb718cc48543e2e244',
#  'a2d940be8dc020e99c4f23fa979994bf',
#  'f82498e55e15c90643967f8a38ddd98c',
#  '53421ba867de46ff359de40e9753711e',
#  '4b972ebb44d4ffc7516c8ff160301ef3',
#  '243ac2a985a19d4df09c21541494dcae',
#  'd1715d9dc331bee79ee781ff26684f8f',
#  '6e87bf75a7ec7e474e90aef4188a7007']

# %% [markdown]
# Projects in the lime bottom explanations

# %%
list(explanations["fold0"]["lime"]["bottom"].keys())[:10]
# Out:
# ['9922bc88316d50dc9fec75ace1f6428d',
#  'cfbd2d9e5b4e27068f9463b029a3d777',
#  '93b9f3988e3941f7acf43b2917e823fe',
#  '975a0183c407402eb3fc4b32fe2df0a5',
#  '77d5e0dc0c59a21425cc417f43266b99',
#  'b53c6be1e99af4ad3b782cbbbc14c209',
#  'd0cfa36c791f4d83123c4b9853983418',
#  'bca108ff397e3f4461a6dbe966996eae',
#  '1e45580a189dcba2b0a581aea5690850',
#  '914ed5ecded471bcb3922ccf422d9265']

# %% [markdown]
# Projects in the treeshap top explanations

# %%
list(explanations["fold0"]["treeshap"]["top"].keys())[:10]
# Out:
# ['cdc83b2eb031d999c123535bf09d24a0',
#  '203c08ca3b1e42a9ba07c93eac4c20cc',
#  'd1fb6298685f8afb718cc48543e2e244',
#  'a2d940be8dc020e99c4f23fa979994bf',
#  'f82498e55e15c90643967f8a38ddd98c',
#  '53421ba867de46ff359de40e9753711e',
#  '4b972ebb44d4ffc7516c8ff160301ef3',
#  '243ac2a985a19d4df09c21541494dcae',
#  'd1715d9dc331bee79ee781ff26684f8f',
#  '6e87bf75a7ec7e474e90aef4188a7007']

# %% [markdown]
# Projects in the treeshap bottom explanations

# %%
list(explanations["fold0"]["treeshap"]["bottom"].keys())[:10]
# Out:
# ['9922bc88316d50dc9fec75ace1f6428d',
#  'cfbd2d9e5b4e27068f9463b029a3d777',
#  '93b9f3988e3941f7acf43b2917e823fe',
#  '975a0183c407402eb3fc4b32fe2df0a5',
#  '77d5e0dc0c59a21425cc417f43266b99',
#  'b53c6be1e99af4ad3b782cbbbc14c209',
#  'd0cfa36c791f4d83123c4b9853983418',
#  'bca108ff397e3f4461a6dbe966996eae',
#  '1e45580a189dcba2b0a581aea5690850',
#  '914ed5ecded471bcb3922ccf422d9265']

# %% [markdown]
# features in the lime top explanations

# %%
len(list(zip(*list(explanations["fold0"]["lime"]["top"].values())[0][:]))[0])

len(data_folds[0]["x_test"][data_folds[0]["x_test"]["Project ID"] == "cdc83b2eb031d999c123535bf09d24a0"].columns[1:])
# Out:
# 575

# %%
print(list(zip(*list(explanations["fold0"]["lime"]["top"].values())[0][:]))[0])
# Out:
# ('Project Cost', 'School State_New Mexico', 'Project Subject Subcategory Tree_Mathematics, Performing Arts', 'School State_Mississippi', 'School State_Nebraska', 'Project Subject Subcategory Tree_Economics, Performing Arts', 'Project Subject Subcategory Tree_College & Career Prep, Environmental Science', 'School State_Oregon', 'Project Subject Subcategory Tree_ESL, Performing Arts', 'Project Resource Category_Technology', 'Project Subject Subcategory Tree_Character Education, Social Sciences', 'Project Subject Category Tree_Health & Sports, Math & Science', 'Project Subject Subcategory Tree_Other, Social Sciences', 'School State_Missouri', 'Project Subject Subcategory Tree_Early Development, Environmental Science', 'Project Subject Subcategory Tree_Community Service, Extracurricular', 'Project Subject Subcategory Tree_Character Education, Civics & Government', 'Project Subject Subcategory Tree_Civics & Government, Community Service', 'Project Subject Subcategory Tree_Foreign Languages, Health & Wellness', 'Project Subject Subcategory Tree_Early Development, Health & Life Science', 'Project Subject Subcategory Tree_Community Service, Economics', 'Project Resource Category_Books', 'Project Subject Subcategory Tree_Extracurricular, Parent Involvement', 'School State_West Virginia', 'School State_Vermont', 'Project Subject Subcategory Tree_Gym & Fitness, Literacy', 'School State_Illinois', 'Project Subject Category Tree_Special Needs, Health & Sports', 'Project Type_Professional Development', 'Project Subject Subcategory Tree_Early Development, Music', 'Project Subject Subcategory Tree_Gym & Fitness, Literature & Writing', 'Project Subject Subcategory Tree_Applied Sciences, Performing Arts', 'Project Subject Subcategory Tree_Performing Arts, Special Needs', 'Project Subject Subcategory Tree_Mathematics, Social Sciences', 'Teacher Project Posted Sequence', 'School City Success Rate', 'Project Subject Subcategory Tree_Character Education, ESL', 'School State_New York', 'Project Subject Subcategory Tree_History & Geography, Performing Arts', 'Project Subject Subcategory Tree_Financial Literacy, Mathematics', 'Project Subject Subcategory Tree_Literature & Writing, Team Sports', 'Project Subject Subcategory Tree_Environmental Science, Extracurricular', 'School State_Pennsylvania', 'Project Subject Subcategory Tree_Community Service, Health & Wellness', 'Project Subject Subcategory Tree_Community Service, Special Needs', 'Project Subject Subcategory Tree_Applied Sciences, Health & Wellness', 'School State_Louisiana', 'Project Subject Subcategory Tree_Character Education, Environmental Science', 'Project Subject Subcategory Tree_College & Career Prep, Health & Life Science', 'School State_Virginia', 'Project Subject Subcategory Tree_Health & Wellness, Mathematics', 'Project Subject Subcategory Tree_History & Geography, Visual Arts', 'Project Subject Subcategory Tree_Music, Social Sciences', 'Project Subject Subcategory Tree_Civics & Government', 'School State_Massachusetts', 'Project Subject Subcategory Tree_Extracurricular', 'Project Subject Subcategory Tree_Environmental Science, Social Sciences', 'Project Subject Subcategory Tree_College & Career Prep, ESL', 'Project Subject Subcategory Tree_History & Geography, Music', 'School Success Rate', 'School State_Rhode Island', 'Project Subject Subcategory Tree_College & Career Prep, Performing Arts', 'Project Subject Subcategory Tree_History & Geography, Special Needs', 'Project Subject Subcategory Tree_Environmental Science, Gym & Fitness', 'Project Subject Subcategory Tree_Health & Life Science, History & Geography', 'Project Subject Subcategory Tree_Extracurricular, Performing Arts', 'School State_North Carolina', 'Project Subject Subcategory Tree_Literacy, Nutrition Education', 'Project Subject Subcategory Tree_Environmental Science, History & Geography', 'Project Subject Subcategory Tree_Applied Sciences, Social Sciences', 'School State_Nevada', 'Project Subject Subcategory Tree_Health ...

# %%
print(data_folds[0]["x_test"][data_folds[0]["x_test"]["Project ID"] == "cdc83b2eb031d999c123535bf09d24a0"].columns[1:])
# Out:
# Index(['Project Posted Month', 'Project Cost', 'School Percentage Free Lunch',
#        'Teacher Project Posted Sequence', 'Teacher Success Rate',
#        'Teacher Success Rate Imputed', 'School City Success Rate',
#        'School City Success Rate Imputed', 'School Success Rate',
#        'School Success Rate Imputed',
#        ...
#        'School State_Washington', 'School State_West Virginia',
#        'School State_Wisconsin', 'School State_Wyoming', 'Teacher Prefix_Dr.',
#        'Teacher Prefix_Mr.', 'Teacher Prefix_Mrs.', 'Teacher Prefix_Ms.',
#        'Teacher Prefix_Mx.', 'Teacher Prefix_Teacher'],
#       dtype='object', length=575)

# %% [markdown]
# features in the lime bottom explanations

# %%
list(zip(*list(explanations["fold0"]["lime"]["bottom"].values())[0][:10]))[0]
# Out:
# ('School State_New Mexico',
#  'Project Cost',
#  'School State_Mississippi',
#  'School State_Oregon',
#  'Project Subject Subcategory Tree_College & Career Prep, Early Development',
#  'Project Subject Category Tree_Music & The Arts, History & Civics',
#  'Project Subject Subcategory Tree_Literature & Writing, Other',
#  'Project Subject Subcategory Tree_Community Service, Environmental Science',
#  'Project Subject Subcategory Tree_Community Service, Mathematics',
#  'Project Subject Subcategory Tree_Civics & Government, Visual Arts')

# %% [markdown]
# features in the treeshap top explanations

# %%
list(zip(*list(explanations["fold0"]["treeshap"]["top"].values())[0][:10]))[0]
# Out:
# ('Project Cost',
#  'School State_Mississippi',
#  'Project Resource Category_Technology',
#  'Teacher Project Posted Sequence',
#  'School City Success Rate',
#  'School Success Rate',
#  'Teacher Success Rate',
#  'Teacher Success Rate Imputed',
#  'School County Success Rate',
#  'Project Count in State')

# %% [markdown]
# features in the treeshap bottom explanations

# %%
list(zip(*list(explanations["fold0"]["treeshap"]["bottom"].values())[0][:10]))[0]
# Out:
# ('Project Cost',
#  'School State_Illinois',
#  'School Success Rate',
#  'Project Resource Category_Technology',
#  'Project Posted Month',
#  'Teacher Project Posted Sequence',
#  'Teacher Success Rate',
#  'Project Count in State',
#  'Project Resource Category_Books',
#  'Teacher Success Rate Imputed')

# %%
project_explanation = explanations["fold0"]["treeshap"]["bottom"]["9922bc88316d50dc9fec75ace1f6428d"]

# Make the feature vs important score list into dictionary
project = {}
for feature in project_explanation:
    if feature[0] not in project.keys():
        project[feature[0]] = feature[1]
        
    else:
        print(f"{feature[0]} has duplicates")

# %%
feature , important_score = project_explanation[0]

# %% [markdown]
# ### Feature space with feature importance score

# %%
feature_space_with_importance = {}

for feature , important_score in  project_explanation:
    if len(feature.split("_")) == 1:
        feature_space_with_importance[feature.split("_")[0]] = important_score
        
    elif feature.split("_")[0] in feature_space_with_importance.keys():
        feature_space_with_importance[feature.split("_")[0]][feature]=  important_score
    else:
        feature_space_with_importance[feature.split("_")[0]]= {}
        feature_space_with_importance[feature.split("_")[0]][feature]=  important_score
        
# compacted_explanation = []
# for feature in compacted_features.keys():
#     #! duplicate keys
#     compacted_explanation.append([feature, max(compacted_features[feature], key= lambda x : abs(x))])

print(feature_space_with_importance)
# Out:
# {'Project Cost': -0.02602504681196933, 'School State': {'School State_Illinois': -0.02180424855480396, 'School State_New York': -0.0015074806829943554, 'School State_New Jersey': -0.0005795116676927136, 'School State_Massachusetts': 0.0005370641225545114, 'School State_Pennsylvania': 0.0005351177916600136, 'School State_Missouri': -0.000510592402297334, 'School State_North Carolina': 0.0004209882833447409, 'School State_New Mexico': -0.0003621141724579502, 'School State_Alabama': -0.00032283463115163614, 'School State_Indiana': -0.0003145353738727863, 'School State_Mississippi': -0.00031287878246075704, 'School State_Michigan': -0.0002755996493579005, 'School State_Colorado': 0.0001629375236461783, 'School State_Nevada': -0.0001612996661060606, 'School State_Ohio': -9.34854031766008e-05, 'School State_Arizona': 8.549149137252244e-05, 'School State_Florida': 6.662429377684021e-05, 'School State_Washington': -6.578171525688958e-05, 'School State_California': 5.3923177929391387e-05, 'School State_Iowa': -4.9219651482417246e-05, 'School State_Kentucky': -4.5080216877977364e-05, 'School State_Utah': 3.3511112160340414e-05, 'School State_Georgia': -2.7305157327646157e-05, 'School State_Maryland': 2.2302824654616415e-05, 'School State_Texas': -1.9749645734918885e-05, 'School State_Oklahoma': 1.85150991910632e-05, 'School State_South Carolina': -1.754725344653707e-05, 'School State_District of Columbia': -6.420547360903584e-06, 'School State_South Dakota': 2.325894820387475e-06, 'School State_Arkansas': -1.203807732963469e-06, 'School State_Alaska': 0.0, 'School State_Connecticut': 0.0, 'School State_Delaware': 0.0, 'School State_Hawaii': 0.0, 'School State_Idaho': 0.0, 'School State_Kansas': 0.0, 'School State_Louisiana': 0.0, 'School State_Maine': 0.0, 'School State_Minnesota': 0.0, 'School State_Montana': 0.0, 'School State_Nebraska': 0.0, 'School State_New Hampshire': 0.0, 'School State_North Dakota': 0.0, 'School State_Oregon': 0.0, 'School State_Rhode Island': 0.0, 'School State_Tennessee': 0.0, 'School State_Unknown': 0.0, 'School State_Vermont': 0.0, 'School State_Virginia': 0.0, 'School State_West Virginia': 0.0, 'School State_Wisconsin': 0.0, 'School State_Wyoming': 0.0}, 'School Success Rate': -0.017505583778207667, 'Project Resource Category': {'Project Resource Category_Technology': -0.006742306857236144, 'Project Resource Category_Books': 0.0028691998338661053, 'Project Resource Category_Supplies': -0.002422231425857717, 'Project Resource Category_Trips': 3.7464030810951954e-05, 'Project Resource Category_Other': -7.800931834935909e-06, 'Project Resource Category_Unknown': 0.0, 'Project Resource Category_Visitors': 0.0}, 'Project Posted Month': 0.006214428558841974, 'Teacher Project Posted Sequence': -0.004799128680804188, 'Teacher Success Rate': 0.004406902267389796, 'Project Count in State': -0.00336914051841859, 'Teacher Success Rate Imputed': -0.002817042707292785, 'School Percentage Free Lunch': 0.002125179466502232, 'Teacher Prefix': {'Teacher Prefix_Ms.': -0.0017303964151915352, 'Teacher Prefix_Mrs.': -0.00024137083285950212, 'Teacher Prefix_Teacher': -8.263472653197824e-05, 'Teacher Prefix_Mr.': -6.526877950818743e-07, 'Teacher Prefix_Dr.': 0.0, 'Teacher Prefix_Mx.': 0.0}, 'School Metro Type': {'School Metro Type_urban': -0.0010255550905412746, 'School Metro Type_unknown': -0.0002933678690078523, 'School Metro Type_town': -3.4970082851941696e-05, 'School Metro Type_suburban': 6.96901517585502e-06, 'School Metro Type_rural': 4.28639566507627e-06, 'School Metro Type_Unknown': 0.0}, 'School City Success Rate': -0.0008568011747343007, 'School Success Rate Imputed': -0.00025358081345757457, 'Project Subject Category Tree': {'Project Subject Category Tree_Literacy & Language, Math & Science': -0.00025057993518544207, 'Project Subject Category Tree_Literacy & Language': 0.00023495366200677382, 'Project Subject Category Tree_Literacy & Language, Music & The Arts': 0.00010497482205209962, 'Project Subject Category Tree_Li ...

# %%
# feature_space_with_importance

# %% [markdown]
# ### Activated feature dictionary

# %%
activated_features = {}
for feature in config.CATEGORICAL_COLS:
    activated_features[feature] = f"{feature}_{raw_data[raw_data['Project ID'] == 'cdc83b2eb031d999c123535bf09d24a0' ][feature].values[0]}"

# %%
from compactor.ActivatedCompactor import ActivatedCompactor

# %%
ActivatedCompactor(activated_features).compact(feature_space_with_importance)
# Out:
# [['Project Cost', -0.02602504681196933],
#  ['School State', -0.00031287878246075704],
#  ['School Success Rate', -0.017505583778207667],
#  ['Project Resource Category', -0.006742306857236144],
#  ['Project Posted Month', 0.006214428558841974],
#  ['Teacher Project Posted Sequence', -0.004799128680804188],
#  ['Teacher Success Rate', 0.004406902267389796],
#  ['Project Count in State', -0.00336914051841859],
#  ['Teacher Success Rate Imputed', -0.002817042707292785],
#  ['School Percentage Free Lunch', 0.002125179466502232],
#  ['Teacher Prefix', -0.00024137083285950212],
#  ['School Metro Type', -0.0002933678690078523],
#  ['School City Success Rate', -0.0008568011747343007],
#  ['School Success Rate Imputed', -0.00025358081345757457],
#  ['Project Subject Category Tree', -6.766490165318828e-05],
#  ['Project Grade Level Category', 0.00013671097005499178],
#  ['School City Success Rate Imputed', -0.00022143448928545694],
#  ['Project Subject Subcategory Tree', 1.8585182770038954e-05],
#  ['School County Success Rate', 4.2482024859396006e-05],
#  ['School County Success Rate Imputed', 0.0],
#  ['Project Type', 0.0]]

# %% [markdown]
# ### Max abs Compact

# %% [markdown]
# Take all the sub features and take the higher importance score as the score for parent feature

# %%
compacted_feature_abs_max = []

for parent_feature, children_space in feature_space_with_importance.items():
    if parent_feature in config.CATEGORICAL_COLS:
        compacted_feature_abs_max.append([parent_feature,  max(children_space.values(), key= lambda x : abs(x))])
    else:
        compacted_feature_abs_max.append([parent_feature, feature_space_with_importance[parent_feature]])

# %%
compacted_feature_abs_max
# Out:
# [['Project Cost', -0.02602504681196933],
#  ['School State', -0.02180424855480396],
#  ['School Success Rate', -0.017505583778207667],
#  ['Project Resource Category', -0.006742306857236144],
#  ['Project Posted Month', 0.006214428558841974],
#  ['Teacher Project Posted Sequence', -0.004799128680804188],
#  ['Teacher Success Rate', 0.004406902267389796],
#  ['Project Count in State', -0.00336914051841859],
#  ['Teacher Success Rate Imputed', -0.002817042707292785],
#  ['School Percentage Free Lunch', 0.002125179466502232],
#  ['Teacher Prefix', -0.0017303964151915352],
#  ['School Metro Type', -0.0010255550905412746],
#  ['School City Success Rate', -0.0008568011747343007],
#  ['School Success Rate Imputed', -0.00025358081345757457],
#  ['Project Subject Category Tree', -0.00025057993518544207],
#  ['Project Grade Level Category', -0.0002342117682837852],
#  ['School City Success Rate Imputed', -0.00022143448928545694],
#  ['Project Subject Subcategory Tree', -8.532835632649948e-05],
#  ['School County Success Rate', 4.2482024859396006e-05],
#  ['School County Success Rate Imputed', 0.0],
#  ['Project Type', 0.0]]

# %%
from compactor.MaxCompactor import MaxCompactor
MaxCompactor(config.CATEGORICAL_COLS).compact(feature_space_with_importance)
# Out:
# [['Project Cost', -0.02602504681196933],
#  ['School State', -0.02180424855480396],
#  ['School Success Rate', -0.017505583778207667],
#  ['Project Resource Category', -0.006742306857236144],
#  ['Project Posted Month', 0.006214428558841974],
#  ['Teacher Project Posted Sequence', -0.004799128680804188],
#  ['Teacher Success Rate', 0.004406902267389796],
#  ['Project Count in State', -0.00336914051841859],
#  ['Teacher Success Rate Imputed', -0.002817042707292785],
#  ['School Percentage Free Lunch', 0.002125179466502232],
#  ['Teacher Prefix', -0.0017303964151915352],
#  ['School Metro Type', -0.0010255550905412746],
#  ['School City Success Rate', -0.0008568011747343007],
#  ['School Success Rate Imputed', -0.00025358081345757457],
#  ['Project Subject Category Tree', -0.00025057993518544207],
#  ['Project Grade Level Category', -0.0002342117682837852],
#  ['School City Success Rate Imputed', -0.00022143448928545694],
#  ['Project Subject Subcategory Tree', -8.532835632649948e-05],
#  ['School County Success Rate', 4.2482024859396006e-05],
#  ['School County Success Rate Imputed', 0.0],
#  ['Project Type', 0.0]]

# %% [markdown]
# ### Activated feature compact: Take the important feature score of the activated feature as the score for parent feature

# %% [markdown]
# Take all the sub features and take the higher importance score as the score for parent feature

# %%
from compactor.ActivatedCompactor import ActivatedCompactor
ActivatedCompactor(activated_features).compact(feature_space_with_importance)
# Out:
# [['Project Cost', -0.02602504681196933],
#  ['School State', -0.00031287878246075704],
#  ['School Success Rate', -0.017505583778207667],
#  ['Project Resource Category', -0.006742306857236144],
#  ['Project Posted Month', 0.006214428558841974],
#  ['Teacher Project Posted Sequence', -0.004799128680804188],
#  ['Teacher Success Rate', 0.004406902267389796],
#  ['Project Count in State', -0.00336914051841859],
#  ['Teacher Success Rate Imputed', -0.002817042707292785],
#  ['School Percentage Free Lunch', 0.002125179466502232],
#  ['Teacher Prefix', -0.00024137083285950212],
#  ['School Metro Type', -0.0002933678690078523],
#  ['School City Success Rate', -0.0008568011747343007],
#  ['School Success Rate Imputed', -0.00025358081345757457],
#  ['Project Subject Category Tree', -6.766490165318828e-05],
#  ['Project Grade Level Category', 0.00013671097005499178],
#  ['School City Success Rate Imputed', -0.00022143448928545694],
#  ['Project Subject Subcategory Tree', 1.8585182770038954e-05],
#  ['School County Success Rate', 4.2482024859396006e-05],
#  ['School County Success Rate Imputed', 0.0],
#  ['Project Type', 0.0]]

# %%
activated_features
# Out:
# {'Project Type': 'Project Type_Teacher-Led',
#  'Project Subject Category Tree': 'Project Subject Category Tree_Math & Science',
#  'Project Subject Subcategory Tree': 'Project Subject Subcategory Tree_Mathematics',
#  'Project Grade Level Category': 'Project Grade Level Category_Grades PreK-2',
#  'Project Resource Category': 'Project Resource Category_Technology',
#  'School Metro Type': 'School Metro Type_unknown',
#  'School State': 'School State_Mississippi',
#  'Teacher Prefix': 'Teacher Prefix_Mrs.'}

# %%
activated_features["School State"]
# Out:
# 'School State_Mississippi'

# %%
compacted_project_explanation_activated_importance =[]

for parent_feature in feature_space_with_importance.keys():
    if parent_feature in activated_features.keys():
        compacted_project_explanation_activated_importance.append([parent_feature,feature_space_with_importance[parent_feature][activated_features[parent_feature]]])
    else:
        compacted_project_explanation_activated_importance.append([parent_feature,feature_space_with_importance[parent_feature]])

print(compacted_project_explanation_activated_importance)
# Out:
# [['Project Cost', -0.02602504681196933], ['School State', -0.00031287878246075704], ['School Success Rate', -0.017505583778207667], ['Project Resource Category', -0.006742306857236144], ['Project Posted Month', 0.006214428558841974], ['Teacher Project Posted Sequence', -0.004799128680804188], ['Teacher Success Rate', 0.004406902267389796], ['Project Count in State', -0.00336914051841859], ['Teacher Success Rate Imputed', -0.002817042707292785], ['School Percentage Free Lunch', 0.002125179466502232], ['Teacher Prefix', -0.00024137083285950212], ['School Metro Type', -0.0002933678690078523], ['School City Success Rate', -0.0008568011747343007], ['School Success Rate Imputed', -0.00025358081345757457], ['Project Subject Category Tree', -6.766490165318828e-05], ['Project Grade Level Category', 0.00013671097005499178], ['School City Success Rate Imputed', -0.00022143448928545694], ['Project Subject Subcategory Tree', 1.8585182770038954e-05], ['School County Success Rate', 4.2482024859396006e-05], ['School County Success Rate Imputed', 0.0], ['Project Type', 0.0]]

# %% [markdown]
# ### Not Activated feature compact: Take the important feature score of abs max of the activated feature as the score for parent feature

# %% [markdown]
# Take all the sub features and take the higher importance score as the score for parent feature

# %%
from compactor.MaxNonActivatedCompactor import MaxNonActivatedCompactor
print(MaxNonActivatedCompactor(activated_features).compact(feature_space_with_importance))
# Out:
# [['Project Cost', -0.02602504681196933], ['School State', -0.02180424855480396], ['School Success Rate', -0.017505583778207667], ['Project Resource Category', 0.0028691998338661053], ['Project Posted Month', 0.006214428558841974], ['Teacher Project Posted Sequence', -0.004799128680804188], ['Teacher Success Rate', 0.004406902267389796], ['Project Count in State', -0.00336914051841859], ['Teacher Success Rate Imputed', -0.002817042707292785], ['School Percentage Free Lunch', 0.002125179466502232], ['Teacher Prefix', -0.0017303964151915352], ['School Metro Type', -0.0010255550905412746], ['School City Success Rate', -0.0008568011747343007], ['School Success Rate Imputed', -0.00025358081345757457], ['Project Subject Category Tree', -0.00025057993518544207], ['Project Grade Level Category', -0.0002342117682837852], ['School City Success Rate Imputed', -0.00022143448928545694], ['Project Subject Subcategory Tree', -8.532835632649948e-05], ['School County Success Rate', 4.2482024859396006e-05], ['School County Success Rate Imputed', 0.0], ['Project Type', 0]]

# %%
project_explanation_non_activated_max =[]

for parent_feature in feature_space_with_importance.keys():
    if parent_feature in config.CATEGORICAL_COLS:
        max_importance = 0
        for feature, importance in feature_space_with_importance[parent_feature].items():
            if feature != activated_features[parent_feature] and abs(importance) > abs(max_importance) :
                max_importance = importance
                
        project_explanation_non_activated_max.append([parent_feature,max_importance])
        
    else:
        project_explanation_non_activated_max.append([parent_feature,feature_space_with_importance[parent_feature]])
        
print(project_explanation_non_activated_max)
# Out:
# [['Project Cost', -0.02602504681196933], ['School State', -0.02180424855480396], ['School Success Rate', -0.017505583778207667], ['Project Resource Category', 0.0028691998338661053], ['Project Posted Month', 0.006214428558841974], ['Teacher Project Posted Sequence', -0.004799128680804188], ['Teacher Success Rate', 0.004406902267389796], ['Project Count in State', -0.00336914051841859], ['Teacher Success Rate Imputed', -0.002817042707292785], ['School Percentage Free Lunch', 0.002125179466502232], ['Teacher Prefix', -0.0017303964151915352], ['School Metro Type', -0.0010255550905412746], ['School City Success Rate', -0.0008568011747343007], ['School Success Rate Imputed', -0.00025358081345757457], ['Project Subject Category Tree', -0.00025057993518544207], ['Project Grade Level Category', -0.0002342117682837852], ['School City Success Rate Imputed', -0.00022143448928545694], ['Project Subject Subcategory Tree', -8.532835632649948e-05], ['School County Success Rate', 4.2482024859396006e-05], ['School County Success Rate Imputed', 0.0], ['Project Type', 0]]

# %% [markdown]
# Take the project explanations --> feature A_1 : s1, feature A_2: s2, feature A_4: s3, feature A_4: s4 ....
#
# Group the explanations based on max score --> feature A_1 : s1, feature A_2: s2, feature A_4: s3, feature A_4: s4 .... -->
#                             fature A : s = max (abs(s1, s2, s3 s4 ...))
#
#
# Take the explanation for a project  and Take feature space of the project, multply both and take the some
# Group the explanations based on max score --> feature A_1 : s1, feature A_2: s2, feature A_4: s3, feature A_4: s4 .... -->
#                             fature A : s =  (s1, s2, s3 s4 ...) * ( 1, 0, 0 , 0, .. )

# %%
# break

# %%
from compactor.MaxCompactor import MaxCompactor

# %% [markdown]
# ### Let's say i am considering the first explanation in the treeshap and the first explanation in the lime with compacted feature space.
#
# The explanation pertains to the projects considered high critical according to the model's evaluation.

# %% [markdown]
# ### Compact based on Max absolute value

# %%
disagreement = Disagreement(explanations["fold0"]["treeshap"]["top"]["cdc83b2eb031d999c123535bf09d24a0"], explanations["fold0"]["lime"]["top"]["cdc83b2eb031d999c123535bf09d24a0"])

# %%
print(disagreement.get_rank_agreement(20))
# Out:
# 0.05

# %%
disagreement.sorted_explanation1[:20]
# Out:
# [['Project Cost', 0.05714906222884565],
#  ['School State_Mississippi', 0.041025607910487455],
#  ['Project Resource Category_Technology', 0.022928445398821395],
#  ['Teacher Project Posted Sequence', 0.017752762721138425],
#  ['School City Success Rate', 0.017585039435300587],
#  ['School Success Rate', 0.014126902513215783],
#  ['Teacher Success Rate', 0.009001123399286826],
#  ['Teacher Success Rate Imputed', 0.0075924428426549185],
#  ['School County Success Rate', 0.005877010966310081],
#  ['Project Count in State', 0.003946468204571829],
#  ['Project Resource Category_Books', 0.0035422505235283095],
#  ['School Metro Type_unknown', 0.003488676856704842],
#  ['Project Resource Category_Supplies', 0.0033089717177392686],
#  ['Project Posted Month', 0.0028910216754434257],
#  ['School Percentage Free Lunch', 0.0027158185248663358],
#  ['Project Subject Subcategory Tree_Mathematics', 0.002388253706089927],
#  ['Project Subject Category Tree_Math & Science', 0.0022903894063142616],
#  ['Teacher Prefix_Ms.', 0.0016874724042918387],
#  ['Project Grade Level Category_Grades PreK-2', -0.001054697545991985],
#  ['School State_New York', -0.0009630994266080961]]

# %%
disagreement.sorted_explanation2[:20]
# Out:
# [['Project Cost', 0.05828515065993562],
#  ['School State_New Mexico', -0.04561995832431883],
#  ['Project Subject Subcategory Tree_Mathematics, Performing Arts',
#   -0.03652875725130923],
#  ['School State_Mississippi', 0.03525123751671513],
#  ['School State_Nebraska', -0.030140219371630757],
#  ['Project Subject Subcategory Tree_Economics, Performing Arts',
#   0.028696205307718412],
#  ['Project Subject Subcategory Tree_College & Career Prep, Environmental Science',
#   0.025975377818970764],
#  ['School State_Oregon', 0.02477959436814468],
#  ['Project Subject Subcategory Tree_ESL, Performing Arts',
#   0.024418609316633387],
#  ['Project Resource Category_Technology', 0.02412976165593627],
#  ['Project Subject Subcategory Tree_Character Education, Social Sciences',
#   -0.023669453164068096],
#  ['Project Subject Category Tree_Health & Sports, Math & Science',
#   -0.023382474876373693],
#  ['Project Subject Subcategory Tree_Other, Social Sciences',
#   0.023007167202545663],
#  ['School State_Missouri', -0.02271869552126897],
#  ['Project Subject Subcategory Tree_Early Development, Environmental Science',
#   -0.022709285230336752],
#  ['Project Subject Subcategory Tree_Community Service, Extracurricular',
#   -0.02194703678332285],
#  ['Project Subject Subcategory Tree_Character Education, Civics & Government',
#   -0.020616315850737355],
#  ['Project Subject Subcategory Tree_Civics & Government, Community Service',
#   -0.020559947692224117],
#  ['Project Subject Subcategory Tree_Foreign Languages, Health & Wellness',
#   -0.020440728560850788],
#  ['Project Subject Subcategory Tree_Early Development, Health & Life Science',
#   -0.020335872198160646]]

# %%
max_compactor = MaxCompactor(config.CATEGORICAL_COLS)

# %%
disagreement.compact_features(max_compactor)

# %%
disagreement.sorted_explanation1
# Out:
# [['Project Cost', 0.05714906222884565],
#  ['School State', 0.041025607910487455],
#  ['Project Resource Category', 0.022928445398821395],
#  ['Teacher Project Posted Sequence', 0.017752762721138425],
#  ['School City Success Rate', 0.017585039435300587],
#  ['School Success Rate', 0.014126902513215783],
#  ['Teacher Success Rate', 0.009001123399286826],
#  ['Teacher Success Rate Imputed', 0.0075924428426549185],
#  ['School County Success Rate', 0.005877010966310081],
#  ['Project Count in State', 0.003946468204571829],
#  ['School Metro Type', 0.003488676856704842],
#  ['Project Posted Month', 0.0028910216754434257],
#  ['School Percentage Free Lunch', 0.0027158185248663358],
#  ['Project Subject Subcategory Tree', 0.002388253706089927],
#  ['Project Subject Category Tree', 0.0022903894063142616],
#  ['Teacher Prefix', 0.0016874724042918387],
#  ['Project Grade Level Category', -0.001054697545991985],
#  ['School Success Rate Imputed', -0.0007291512318624882],
#  ['School City Success Rate Imputed', -0.00014314810375253727],
#  ['School County Success Rate Imputed', 0.0],
#  ['Project Type', 0.0]]

# %%
disagreement.get_disagreement(20, None)
# Out:
# {'feature_agreement': 0.95,
#  'rank_agreement': 0.1,
#  'sign_agreement': 0.7,
#  'signed_rank_agreement': 0.05}

# %%
disagreement.sorted_explanation1[:20]
# Out:
# [['Project Cost', 0.05714906222884565],
#  ['School State', 0.041025607910487455],
#  ['Project Resource Category', 0.022928445398821395],
#  ['Teacher Project Posted Sequence', 0.017752762721138425],
#  ['School City Success Rate', 0.017585039435300587],
#  ['School Success Rate', 0.014126902513215783],
#  ['Teacher Success Rate', 0.009001123399286826],
#  ['Teacher Success Rate Imputed', 0.0075924428426549185],
#  ['School County Success Rate', 0.005877010966310081],
#  ['Project Count in State', 0.003946468204571829],
#  ['School Metro Type', 0.003488676856704842],
#  ['Project Posted Month', 0.0028910216754434257],
#  ['School Percentage Free Lunch', 0.0027158185248663358],
#  ['Project Subject Subcategory Tree', 0.002388253706089927],
#  ['Project Subject Category Tree', 0.0022903894063142616],
#  ['Teacher Prefix', 0.0016874724042918387],
#  ['Project Grade Level Category', -0.001054697545991985],
#  ['School Success Rate Imputed', -0.0007291512318624882],
#  ['School City Success Rate Imputed', -0.00014314810375253727],
#  ['School County Success Rate Imputed', 0.0]]

# %%
disagreement.sorted_explanation2[:20]
# Out:
# [['Project Cost', 0.05828515065993562],
#  ['School State', -0.04561995832431883],
#  ['Project Subject Subcategory Tree', -0.03652875725130923],
#  ['Project Resource Category', 0.02412976165593627],
#  ['Project Subject Category Tree', -0.023382474876373693],
#  ['Project Type', -0.01874909636736988],
#  ['Teacher Project Posted Sequence', 0.01764274655322783],
#  ['School City Success Rate', 0.01762791127218422],
#  ['School Success Rate', 0.01439123893716053],
#  ['School County Success Rate', 0.010396124467336478],
#  ['Teacher Prefix', -0.009602694849670359],
#  ['Teacher Success Rate Imputed', 0.008948085524911165],
#  ['Teacher Success Rate', 0.00887785459302942],
#  ['School County Success Rate Imputed', -0.0086799413234964],
#  ['Project Posted Month', 0.005683481725688235],
#  ['School Metro Type', 0.00521351220862078],
#  ['School Success Rate Imputed', -0.005064600567585159],
#  ['School City Success Rate Imputed', -0.004505058261636036],
#  ['School Percentage Free Lunch', 0.0038863764057131076],
#  ['Project Count in State', 0.003006706209883576]]

# %% [markdown]
# ### Compact based on Activated value

# %%
disagreement = Disagreement(explanations["fold0"]["treeshap"]["top"]["cdc83b2eb031d999c123535bf09d24a0"], explanations["fold0"]["lime"]["top"]["cdc83b2eb031d999c123535bf09d24a0"])

# %%
disagreement.sorted_explanation1[:20]
# Out:
# [['Project Cost', 0.05714906222884565],
#  ['School State_Mississippi', 0.041025607910487455],
#  ['Project Resource Category_Technology', 0.022928445398821395],
#  ['Teacher Project Posted Sequence', 0.017752762721138425],
#  ['School City Success Rate', 0.017585039435300587],
#  ['School Success Rate', 0.014126902513215783],
#  ['Teacher Success Rate', 0.009001123399286826],
#  ['Teacher Success Rate Imputed', 0.0075924428426549185],
#  ['School County Success Rate', 0.005877010966310081],
#  ['Project Count in State', 0.003946468204571829],
#  ['Project Resource Category_Books', 0.0035422505235283095],
#  ['School Metro Type_unknown', 0.003488676856704842],
#  ['Project Resource Category_Supplies', 0.0033089717177392686],
#  ['Project Posted Month', 0.0028910216754434257],
#  ['School Percentage Free Lunch', 0.0027158185248663358],
#  ['Project Subject Subcategory Tree_Mathematics', 0.002388253706089927],
#  ['Project Subject Category Tree_Math & Science', 0.0022903894063142616],
#  ['Teacher Prefix_Ms.', 0.0016874724042918387],
#  ['Project Grade Level Category_Grades PreK-2', -0.001054697545991985],
#  ['School State_New York', -0.0009630994266080961]]

# %%
disagreement.sorted_explanation2[:20]
# Out:
# [['Project Cost', 0.05828515065993562],
#  ['School State_New Mexico', -0.04561995832431883],
#  ['Project Subject Subcategory Tree_Mathematics, Performing Arts',
#   -0.03652875725130923],
#  ['School State_Mississippi', 0.03525123751671513],
#  ['School State_Nebraska', -0.030140219371630757],
#  ['Project Subject Subcategory Tree_Economics, Performing Arts',
#   0.028696205307718412],
#  ['Project Subject Subcategory Tree_College & Career Prep, Environmental Science',
#   0.025975377818970764],
#  ['School State_Oregon', 0.02477959436814468],
#  ['Project Subject Subcategory Tree_ESL, Performing Arts',
#   0.024418609316633387],
#  ['Project Resource Category_Technology', 0.02412976165593627],
#  ['Project Subject Subcategory Tree_Character Education, Social Sciences',
#   -0.023669453164068096],
#  ['Project Subject Category Tree_Health & Sports, Math & Science',
#   -0.023382474876373693],
#  ['Project Subject Subcategory Tree_Other, Social Sciences',
#   0.023007167202545663],
#  ['School State_Missouri', -0.02271869552126897],
#  ['Project Subject Subcategory Tree_Early Development, Environmental Science',
#   -0.022709285230336752],
#  ['Project Subject Subcategory Tree_Community Service, Extracurricular',
#   -0.02194703678332285],
#  ['Project Subject Subcategory Tree_Character Education, Civics & Government',
#   -0.020616315850737355],
#  ['Project Subject Subcategory Tree_Civics & Government, Community Service',
#   -0.020559947692224117],
#  ['Project Subject Subcategory Tree_Foreign Languages, Health & Wellness',
#   -0.020440728560850788],
#  ['Project Subject Subcategory Tree_Early Development, Health & Life Science',
#   -0.020335872198160646]]

# %%
activated_features = {}
for feature in config.CATEGORICAL_COLS:
    activated_features[feature] = f"{feature}_{raw_data[raw_data['Project ID'] == 'cdc83b2eb031d999c123535bf09d24a0' ][feature].values[0]}"

# %%
activated_compactor = ActivatedCompactor(activated_features)

# %%
disagreement.compact_features(activated_compactor)

# %%
disagreement.get_disagreement(20, None)
# Out:
# {'feature_agreement': 1.0,
#  'rank_agreement': 0.35,
#  'sign_agreement': 0.95,
#  'signed_rank_agreement': 0.35}

# %%
disagreement.sorted_explanation1[:20]
# Out:
# [['Project Cost', 0.05714906222884565],
#  ['School State', 0.041025607910487455],
#  ['Project Resource Category', 0.022928445398821395],
#  ['Teacher Project Posted Sequence', 0.017752762721138425],
#  ['School City Success Rate', 0.017585039435300587],
#  ['School Success Rate', 0.014126902513215783],
#  ['Teacher Success Rate', 0.009001123399286826],
#  ['Teacher Success Rate Imputed', 0.0075924428426549185],
#  ['School County Success Rate', 0.005877010966310081],
#  ['Project Count in State', 0.003946468204571829],
#  ['School Metro Type', 0.003488676856704842],
#  ['Project Posted Month', 0.0028910216754434257],
#  ['School Percentage Free Lunch', 0.0027158185248663358],
#  ['Project Subject Subcategory Tree', 0.002388253706089927],
#  ['Project Subject Category Tree', 0.0022903894063142616],
#  ['Project Grade Level Category', -0.001054697545991985],
#  ['School Success Rate Imputed', -0.0007291512318624882],
#  ['Teacher Prefix', 0.00027374011408255684],
#  ['School City Success Rate Imputed', -0.00014314810375253727],
#  ['School County Success Rate Imputed', 0.0]]

# %%
disagreement.sorted_explanation2[:20]
# Out:
# [['Project Cost', 0.05828515065993562],
#  ['School State', 0.03525123751671513],
#  ['Project Resource Category', 0.02412976165593627],
#  ['Teacher Project Posted Sequence', 0.01764274655322783],
#  ['School City Success Rate', 0.01762791127218422],
#  ['School Success Rate', 0.01439123893716053],
#  ['School County Success Rate', 0.010396124467336478],
#  ['Teacher Success Rate Imputed', 0.008948085524911165],
#  ['Teacher Success Rate', 0.00887785459302942],
#  ['School County Success Rate Imputed', -0.0086799413234964],
#  ['Project Posted Month', 0.005683481725688235],
#  ['School Metro Type', 0.00521351220862078],
#  ['School Success Rate Imputed', -0.005064600567585159],
#  ['School City Success Rate Imputed', -0.004505058261636036],
#  ['School Percentage Free Lunch', 0.0038863764057131076],
#  ['Project Count in State', 0.003006706209883576],
#  ['Project Grade Level Category', -0.0017520537476009201],
#  ['Project Subject Category Tree', 0.0017236348728642999],
#  ['Project Subject Subcategory Tree', 1.5403463765332284e-05],
#  ['Teacher Prefix', 1.4317070653925565e-05]]

# %% [markdown]
# ### Compact based on Not Activated value

# %%
from compactor.MaxNonActivatedCompactor import MaxNonActivatedCompactor

# %%
disagreement = Disagreement(explanations["fold0"]["treeshap"]["top"]["cdc83b2eb031d999c123535bf09d24a0"], explanations["fold0"]["lime"]["top"]["cdc83b2eb031d999c123535bf09d24a0"])

# %%
disagreement.sorted_explanation1[:20]
# Out:
# [['Project Cost', 0.05714906222884565],
#  ['School State_Mississippi', 0.041025607910487455],
#  ['Project Resource Category_Technology', 0.022928445398821395],
#  ['Teacher Project Posted Sequence', 0.017752762721138425],
#  ['School City Success Rate', 0.017585039435300587],
#  ['School Success Rate', 0.014126902513215783],
#  ['Teacher Success Rate', 0.009001123399286826],
#  ['Teacher Success Rate Imputed', 0.0075924428426549185],
#  ['School County Success Rate', 0.005877010966310081],
#  ['Project Count in State', 0.003946468204571829],
#  ['Project Resource Category_Books', 0.0035422505235283095],
#  ['School Metro Type_unknown', 0.003488676856704842],
#  ['Project Resource Category_Supplies', 0.0033089717177392686],
#  ['Project Posted Month', 0.0028910216754434257],
#  ['School Percentage Free Lunch', 0.0027158185248663358],
#  ['Project Subject Subcategory Tree_Mathematics', 0.002388253706089927],
#  ['Project Subject Category Tree_Math & Science', 0.0022903894063142616],
#  ['Teacher Prefix_Ms.', 0.0016874724042918387],
#  ['Project Grade Level Category_Grades PreK-2', -0.001054697545991985],
#  ['School State_New York', -0.0009630994266080961]]

# %%
disagreement.sorted_explanation2[:20]
# Out:
# [['Project Cost', 0.05828515065993562],
#  ['School State_New Mexico', -0.04561995832431883],
#  ['Project Subject Subcategory Tree_Mathematics, Performing Arts',
#   -0.03652875725130923],
#  ['School State_Mississippi', 0.03525123751671513],
#  ['School State_Nebraska', -0.030140219371630757],
#  ['Project Subject Subcategory Tree_Economics, Performing Arts',
#   0.028696205307718412],
#  ['Project Subject Subcategory Tree_College & Career Prep, Environmental Science',
#   0.025975377818970764],
#  ['School State_Oregon', 0.02477959436814468],
#  ['Project Subject Subcategory Tree_ESL, Performing Arts',
#   0.024418609316633387],
#  ['Project Resource Category_Technology', 0.02412976165593627],
#  ['Project Subject Subcategory Tree_Character Education, Social Sciences',
#   -0.023669453164068096],
#  ['Project Subject Category Tree_Health & Sports, Math & Science',
#   -0.023382474876373693],
#  ['Project Subject Subcategory Tree_Other, Social Sciences',
#   0.023007167202545663],
#  ['School State_Missouri', -0.02271869552126897],
#  ['Project Subject Subcategory Tree_Early Development, Environmental Science',
#   -0.022709285230336752],
#  ['Project Subject Subcategory Tree_Community Service, Extracurricular',
#   -0.02194703678332285],
#  ['Project Subject Subcategory Tree_Character Education, Civics & Government',
#   -0.020616315850737355],
#  ['Project Subject Subcategory Tree_Civics & Government, Community Service',
#   -0.020559947692224117],
#  ['Project Subject Subcategory Tree_Foreign Languages, Health & Wellness',
#   -0.020440728560850788],
#  ['Project Subject Subcategory Tree_Early Development, Health & Life Science',
#   -0.020335872198160646]]

# %%
activated_features = {}
for feature in config.CATEGORICAL_COLS:
    activated_features[feature] = f"{feature}_{raw_data[raw_data['Project ID'] == 'cdc83b2eb031d999c123535bf09d24a0' ][feature].values[0]}"

# %%
max_activated_compactor = MaxNonActivatedCompactor(activated_features)

# %%
disagreement.compact_features(max_activated_compactor)

# %%
disagreement.get_disagreement(20, None)
# Out:
# {'feature_agreement': 0.95,
#  'rank_agreement': 0.05,
#  'sign_agreement': 0.8,
#  'signed_rank_agreement': 0.05}

# %%
disagreement.sorted_explanation1[:20]
# Out:
# [['Project Cost', 0.05714906222884565],
#  ['Teacher Project Posted Sequence', 0.017752762721138425],
#  ['School City Success Rate', 0.017585039435300587],
#  ['School Success Rate', 0.014126902513215783],
#  ['Teacher Success Rate', 0.009001123399286826],
#  ['Teacher Success Rate Imputed', 0.0075924428426549185],
#  ['School County Success Rate', 0.005877010966310081],
#  ['Project Count in State', 0.003946468204571829],
#  ['Project Resource Category', 0.0035422505235283095],
#  ['Project Posted Month', 0.0028910216754434257],
#  ['School Percentage Free Lunch', 0.0027158185248663358],
#  ['Teacher Prefix', 0.0016874724042918387],
#  ['School State', -0.0009630994266080961],
#  ['School Success Rate Imputed', -0.0007291512318624882],
#  ['School Metro Type', 0.0004618775357312188],
#  ['Project Subject Subcategory Tree', -0.0002500308155322273],
#  ['Project Subject Category Tree', -0.00023901742039697638],
#  ['School City Success Rate Imputed', -0.00014314810375253727],
#  ['Project Grade Level Category', -0.00013460658772146417],
#  ['School County Success Rate Imputed', 0.0]]

# %%
disagreement.sorted_explanation2[:20]
# Out:
# [['Project Cost', 0.05828515065993562],
#  ['School State', -0.04561995832431883],
#  ['Project Subject Subcategory Tree', -0.03652875725130923],
#  ['Project Subject Category Tree', -0.023382474876373693],
#  ['Project Resource Category', 0.02017981543707445],
#  ['Project Type', -0.01874909636736988],
#  ['Teacher Project Posted Sequence', 0.01764274655322783],
#  ['School City Success Rate', 0.01762791127218422],
#  ['School Success Rate', 0.01439123893716053],
#  ['School County Success Rate', 0.010396124467336478],
#  ['Teacher Prefix', -0.009602694849670359],
#  ['Teacher Success Rate Imputed', 0.008948085524911165],
#  ['Teacher Success Rate', 0.00887785459302942],
#  ['School County Success Rate Imputed', -0.0086799413234964],
#  ['Project Posted Month', 0.005683481725688235],
#  ['School Success Rate Imputed', -0.005064600567585159],
#  ['School City Success Rate Imputed', -0.004505058261636036],
#  ['School Percentage Free Lunch', 0.0038863764057131076],
#  ['Project Count in State', 0.003006706209883576],
#  ['School Metro Type', -0.0025868249597884667]]

# %% [markdown]
# #### All the metrics shows that there is significant disagreement for the first explanation
#
# Based on top 20 features in the first explanation of lime and treeshap
#
#
# Feature Agreement 0.15: The feature agreement score is 0.15. This indicates that the top 20 features in Lime's explanation are different from TreeSHAP's top 20 features.
#
# Rank Agreement 0.05: The rank agreement score is 0.05. This means that not only are the top 20 features different, but there is also a significant difference in the order of these features between Lime and TreeSHAP.
#
# Sign Agreement 0.15: The sign agreement score is 0.15. This suggests that the top 20 features in Lime's explanation have different features compared to TreeSHAP's top 20 features when considering the sign of the feature values.
#
# Signed Rank Agreement 0.05: The signed rank agreement score is 0.05. This implies that the top 20 features in Lime's explanation not only differ in terms of the features themselves but also in their rank and sign when compared to TreeSHAP's top 20 features.

# %% [markdown]
# ### Let's say i am considering the last explanation in the treeshap and the last explanation in the lime with compacted feature space.
#
# The explanation pertains to the projects considered less critical according to the model's evaluation.

# %% [markdown]
# ### Compact based on Max absolute value

# %%
disagreement = Disagreement(explanations["fold0"]["treeshap"]["bottom"]["914ed5ecded471bcb3922ccf422d9265"], explanations["fold0"]["lime"]["bottom"]["914ed5ecded471bcb3922ccf422d9265"])

# %%
disagreement.sorted_explanation1[:20]
# Out:
# [['School Success Rate', -0.02073560551451692],
#  ['Project Resource Category_Books', -0.01770426358118641],
#  ['Project Cost', -0.016155206447674573],
#  ['School City Success Rate', -0.007373891001113861],
#  ['School County Success Rate', -0.006529038491705706],
#  ['Project Resource Category_Technology', -0.006248685005766674],
#  ['Project Posted Month', 0.005906740663720029],
#  ['Teacher Project Posted Sequence', -0.004860845310354307],
#  ['Teacher Success Rate', 0.0041988864940344685],
#  ['School Percentage Free Lunch', -0.003522525960356688],
#  ['Teacher Success Rate Imputed', -0.002740343722766738],
#  ['School State_New York', -0.0014524365215038415],
#  ['Teacher Prefix_Ms.', 0.0014260352586097725],
#  ['Project Resource Category_Supplies', 0.0007945032990460276],
#  ['School Metro Type_urban', -0.0005636251404314408],
#  ['School State_Massachusetts', 0.0005606948675085733],
#  ['School State_Pennsylvania', 0.0005600543254786316],
#  ['School State_New Jersey', -0.000550105219103898],
#  ['Project Count in State', -0.000468491965712019],
#  ['School State_Missouri', -0.00046574554151447957]]

# %%
disagreement.sorted_explanation2[:20]
# Out:
# [['School State_New Mexico', -0.039534328867710765],
#  ['Project Subject Subcategory Tree_Early Development, Team Sports',
#   0.03927456784041016],
#  ['School State_Oregon', 0.0359405748502581],
#  ['Project Subject Category Tree_Health & Sports, History & Civics',
#   0.03567932952839871],
#  ['Project Subject Subcategory Tree_Character Education, Mathematics',
#   0.031610236047156556],
#  ['Project Cost', -0.02952929601923634],
#  ['Project Subject Subcategory Tree_Foreign Languages, Literature & Writing',
#   -0.029357881597820344],
#  ['Project Subject Subcategory Tree_Environmental Science, Music',
#   0.0287163292291289],
#  ['Project Subject Subcategory Tree_College & Career Prep, Financial Literacy',
#   0.028657001397669433],
#  ['Project Subject Subcategory Tree_Social Sciences, Visual Arts',
#   0.028511500035182127],
#  ['Project Subject Subcategory Tree_Economics, Financial Literacy',
#   -0.0282102779224615],
#  ['Project Subject Subcategory Tree_ESL, History & Geography',
#   0.02800016263929736],
#  ['Project Subject Subcategory Tree_College & Career Prep, Parent Involvement',
#   -0.02797217031202549],
#  ['School State_Mississippi', -0.02748437033623347],
#  ['Project Subject Subcategory Tree_Extracurricular, Literature & Writing',
#   0.02617007353963521],
#  ['Project Subject Subcategory Tree_Other, Visual Arts', 0.02600694510316824],
#  ['Project Subject Subcategory Tree_Extracurricular, Other',
#   0.025872506929650305],
#  ['School Success Rate', -0.025776909203259216],
#  ['Project Subject Subcategory Tree_Economics, Literature & Writing',
#   0.02557531465735924],
#  ['Project Subject Subcategory Tree_Gym & Fitness, Health & Life Science',
#   0.025279784220352305]]

# %%
max_compactor = MaxCompactor(config.CATEGORICAL_COLS)

# %%
disagreement.compact_features(max_compactor)

# %%
disagreement.sorted_explanation1
# Out:
# [['School Success Rate', -0.02073560551451692],
#  ['Project Resource Category', -0.01770426358118641],
#  ['Project Cost', -0.016155206447674573],
#  ['School City Success Rate', -0.007373891001113861],
#  ['School County Success Rate', -0.006529038491705706],
#  ['Project Posted Month', 0.005906740663720029],
#  ['Teacher Project Posted Sequence', -0.004860845310354307],
#  ['Teacher Success Rate', 0.0041988864940344685],
#  ['School Percentage Free Lunch', -0.003522525960356688],
#  ['Teacher Success Rate Imputed', -0.002740343722766738],
#  ['School State', -0.0014524365215038415],
#  ['Teacher Prefix', 0.0014260352586097725],
#  ['School Metro Type', -0.0005636251404314408],
#  ['Project Count in State', -0.000468491965712019],
#  ['Project Subject Category Tree', -0.0004492578398571823],
#  ['Project Grade Level Category', 0.0003245797966610553],
#  ['School City Success Rate Imputed', -0.00025017424301040594],
#  ['Project Subject Subcategory Tree', 0.00020112983026820074],
#  ['School Success Rate Imputed', -0.0001626017453008899],
#  ['School County Success Rate Imputed', 0.0],
#  ['Project Type', 0.0]]

# %%
disagreement.get_disagreement(20, None)
# Out:
# {'feature_agreement': 0.95,
#  'rank_agreement': 0.1,
#  'sign_agreement': 0.75,
#  'signed_rank_agreement': 0.1}

# %%
disagreement.sorted_explanation1[:20]
# Out:
# [['School Success Rate', -0.02073560551451692],
#  ['Project Resource Category', -0.01770426358118641],
#  ['Project Cost', -0.016155206447674573],
#  ['School City Success Rate', -0.007373891001113861],
#  ['School County Success Rate', -0.006529038491705706],
#  ['Project Posted Month', 0.005906740663720029],
#  ['Teacher Project Posted Sequence', -0.004860845310354307],
#  ['Teacher Success Rate', 0.0041988864940344685],
#  ['School Percentage Free Lunch', -0.003522525960356688],
#  ['Teacher Success Rate Imputed', -0.002740343722766738],
#  ['School State', -0.0014524365215038415],
#  ['Teacher Prefix', 0.0014260352586097725],
#  ['School Metro Type', -0.0005636251404314408],
#  ['Project Count in State', -0.000468491965712019],
#  ['Project Subject Category Tree', -0.0004492578398571823],
#  ['Project Grade Level Category', 0.0003245797966610553],
#  ['School City Success Rate Imputed', -0.00025017424301040594],
#  ['Project Subject Subcategory Tree', 0.00020112983026820074],
#  ['School Success Rate Imputed', -0.0001626017453008899],
#  ['School County Success Rate Imputed', 0.0]]

# %%
disagreement.sorted_explanation2[:20]
# Out:
# [['School State', -0.039534328867710765],
#  ['Project Subject Subcategory Tree', 0.03927456784041016],
#  ['Project Subject Category Tree', 0.03567932952839871],
#  ['Project Cost', -0.02952929601923634],
#  ['School Success Rate', -0.025776909203259216],
#  ['Project Resource Category', -0.023836287905638617],
#  ['Project Type', -0.01503048269510653],
#  ['Teacher Success Rate', 0.012813475583557795],
#  ['Teacher Prefix', -0.009125173179515167],
#  ['Teacher Success Rate Imputed', -0.009009803255737941],
#  ['School Percentage Free Lunch', -0.008126922865584042],
#  ['School City Success Rate', -0.007641181462543814],
#  ['Teacher Project Posted Sequence', -0.0068610916964242825],
#  ['Project Posted Month', 0.006653825060046289],
#  ['School County Success Rate Imputed', -0.006001961298228468],
#  ['School City Success Rate Imputed', -0.005584178358922777],
#  ['School Metro Type', -0.0049755677668917855],
#  ['School Success Rate Imputed', -0.004736606280679097],
#  ['School County Success Rate', -0.004302345526877994],
#  ['Project Grade Level Category', -0.002102650708647841]]

# %% [markdown]
# ### Compact based on Activated value

# %%
disagreement = Disagreement(explanations["fold0"]["treeshap"]["bottom"]["914ed5ecded471bcb3922ccf422d9265"], explanations["fold0"]["lime"]["bottom"]["914ed5ecded471bcb3922ccf422d9265"])

# %%
disagreement.sorted_explanation1[:20]
# Out:
# [['School Success Rate', -0.02073560551451692],
#  ['Project Resource Category_Books', -0.01770426358118641],
#  ['Project Cost', -0.016155206447674573],
#  ['School City Success Rate', -0.007373891001113861],
#  ['School County Success Rate', -0.006529038491705706],
#  ['Project Resource Category_Technology', -0.006248685005766674],
#  ['Project Posted Month', 0.005906740663720029],
#  ['Teacher Project Posted Sequence', -0.004860845310354307],
#  ['Teacher Success Rate', 0.0041988864940344685],
#  ['School Percentage Free Lunch', -0.003522525960356688],
#  ['Teacher Success Rate Imputed', -0.002740343722766738],
#  ['School State_New York', -0.0014524365215038415],
#  ['Teacher Prefix_Ms.', 0.0014260352586097725],
#  ['Project Resource Category_Supplies', 0.0007945032990460276],
#  ['School Metro Type_urban', -0.0005636251404314408],
#  ['School State_Massachusetts', 0.0005606948675085733],
#  ['School State_Pennsylvania', 0.0005600543254786316],
#  ['School State_New Jersey', -0.000550105219103898],
#  ['Project Count in State', -0.000468491965712019],
#  ['School State_Missouri', -0.00046574554151447957]]

# %%
disagreement.sorted_explanation2[:20]
# Out:
# [['School State_New Mexico', -0.039534328867710765],
#  ['Project Subject Subcategory Tree_Early Development, Team Sports',
#   0.03927456784041016],
#  ['School State_Oregon', 0.0359405748502581],
#  ['Project Subject Category Tree_Health & Sports, History & Civics',
#   0.03567932952839871],
#  ['Project Subject Subcategory Tree_Character Education, Mathematics',
#   0.031610236047156556],
#  ['Project Cost', -0.02952929601923634],
#  ['Project Subject Subcategory Tree_Foreign Languages, Literature & Writing',
#   -0.029357881597820344],
#  ['Project Subject Subcategory Tree_Environmental Science, Music',
#   0.0287163292291289],
#  ['Project Subject Subcategory Tree_College & Career Prep, Financial Literacy',
#   0.028657001397669433],
#  ['Project Subject Subcategory Tree_Social Sciences, Visual Arts',
#   0.028511500035182127],
#  ['Project Subject Subcategory Tree_Economics, Financial Literacy',
#   -0.0282102779224615],
#  ['Project Subject Subcategory Tree_ESL, History & Geography',
#   0.02800016263929736],
#  ['Project Subject Subcategory Tree_College & Career Prep, Parent Involvement',
#   -0.02797217031202549],
#  ['School State_Mississippi', -0.02748437033623347],
#  ['Project Subject Subcategory Tree_Extracurricular, Literature & Writing',
#   0.02617007353963521],
#  ['Project Subject Subcategory Tree_Other, Visual Arts', 0.02600694510316824],
#  ['Project Subject Subcategory Tree_Extracurricular, Other',
#   0.025872506929650305],
#  ['School Success Rate', -0.025776909203259216],
#  ['Project Subject Subcategory Tree_Economics, Literature & Writing',
#   0.02557531465735924],
#  ['Project Subject Subcategory Tree_Gym & Fitness, Health & Life Science',
#   0.025279784220352305]]

# %%
activated_features = {}
for feature in config.CATEGORICAL_COLS:
    activated_features[feature] = f"{feature}_{raw_data[raw_data['Project ID'] == '914ed5ecded471bcb3922ccf422d9265' ][feature].values[0]}"

# %%
activated_compactor = ActivatedCompactor(activated_features)

# %%
disagreement.compact_features(activated_compactor)

# %%
disagreement.get_disagreement(20, None)
# Out:
# {'feature_agreement': 1.0,
#  'rank_agreement': 0.05,
#  'sign_agreement': 0.8,
#  'signed_rank_agreement': 0.05}

# %%
disagreement.sorted_explanation1[:20]
# Out:
# [['School Success Rate', -0.02073560551451692],
#  ['Project Resource Category', -0.01770426358118641],
#  ['Project Cost', -0.016155206447674573],
#  ['School City Success Rate', -0.007373891001113861],
#  ['School County Success Rate', -0.006529038491705706],
#  ['Project Posted Month', 0.005906740663720029],
#  ['Teacher Project Posted Sequence', -0.004860845310354307],
#  ['Teacher Success Rate', 0.0041988864940344685],
#  ['School Percentage Free Lunch', -0.003522525960356688],
#  ['Teacher Success Rate Imputed', -0.002740343722766738],
#  ['School Metro Type', -0.0005636251404314408],
#  ['Project Count in State', -0.000468491965712019],
#  ['Teacher Prefix', 0.00044330299691011985],
#  ['School State', -0.0003201726766610591],
#  ['School City Success Rate Imputed', -0.00025017424301040594],
#  ['Project Subject Category Tree', 0.0002435002798051755],
#  ['Project Subject Subcategory Tree', 0.00020112983026820074],
#  ['School Success Rate Imputed', -0.0001626017453008899],
#  ['Project Grade Level Category', 1.551365806335525e-05],
#  ['School County Success Rate Imputed', 0.0]]

# %%
disagreement.sorted_explanation2[:20]
# Out:
# [['Project Cost', -0.02952929601923634],
#  ['School Success Rate', -0.025776909203259216],
#  ['Project Resource Category', -0.019918174049804022],
#  ['Teacher Success Rate', 0.012813475583557795],
#  ['Teacher Success Rate Imputed', -0.009009803255737941],
#  ['School Percentage Free Lunch', -0.008126922865584042],
#  ['School City Success Rate', -0.007641181462543814],
#  ['Teacher Project Posted Sequence', -0.0068610916964242825],
#  ['Project Posted Month', 0.006653825060046289],
#  ['School County Success Rate Imputed', -0.006001961298228468],
#  ['School City Success Rate Imputed', -0.005584178358922777],
#  ['School Success Rate Imputed', -0.004736606280679097],
#  ['School County Success Rate', -0.004302345526877994],
#  ['Project Subject Category Tree', 0.002089182444430119],
#  ['Project Count in State', 0.002015427891416808],
#  ['School State', 0.0009187866139342211],
#  ['School Metro Type', -0.0008567512498406881],
#  ['Teacher Prefix', 0.0006970026340453418],
#  ['Project Grade Level Category', 0.0006967168036107048],
#  ['Project Subject Subcategory Tree', -0.0002889716529175181]]

# %% [markdown]
# ### Compact based on Not Activated value

# %%
from compactor.MaxNonActivatedCompactor import MaxNonActivatedCompactor

# %%
disagreement = Disagreement(explanations["fold0"]["treeshap"]["bottom"]["914ed5ecded471bcb3922ccf422d9265"], explanations["fold0"]["lime"]["bottom"]["914ed5ecded471bcb3922ccf422d9265"])

# %%
disagreement.sorted_explanation1[:20]
# Out:
# [['School Success Rate', -0.02073560551451692],
#  ['Project Resource Category_Books', -0.01770426358118641],
#  ['Project Cost', -0.016155206447674573],
#  ['School City Success Rate', -0.007373891001113861],
#  ['School County Success Rate', -0.006529038491705706],
#  ['Project Resource Category_Technology', -0.006248685005766674],
#  ['Project Posted Month', 0.005906740663720029],
#  ['Teacher Project Posted Sequence', -0.004860845310354307],
#  ['Teacher Success Rate', 0.0041988864940344685],
#  ['School Percentage Free Lunch', -0.003522525960356688],
#  ['Teacher Success Rate Imputed', -0.002740343722766738],
#  ['School State_New York', -0.0014524365215038415],
#  ['Teacher Prefix_Ms.', 0.0014260352586097725],
#  ['Project Resource Category_Supplies', 0.0007945032990460276],
#  ['School Metro Type_urban', -0.0005636251404314408],
#  ['School State_Massachusetts', 0.0005606948675085733],
#  ['School State_Pennsylvania', 0.0005600543254786316],
#  ['School State_New Jersey', -0.000550105219103898],
#  ['Project Count in State', -0.000468491965712019],
#  ['School State_Missouri', -0.00046574554151447957]]

# %%
disagreement.sorted_explanation2[:20]
# Out:
# [['School State_New Mexico', -0.039534328867710765],
#  ['Project Subject Subcategory Tree_Early Development, Team Sports',
#   0.03927456784041016],
#  ['School State_Oregon', 0.0359405748502581],
#  ['Project Subject Category Tree_Health & Sports, History & Civics',
#   0.03567932952839871],
#  ['Project Subject Subcategory Tree_Character Education, Mathematics',
#   0.031610236047156556],
#  ['Project Cost', -0.02952929601923634],
#  ['Project Subject Subcategory Tree_Foreign Languages, Literature & Writing',
#   -0.029357881597820344],
#  ['Project Subject Subcategory Tree_Environmental Science, Music',
#   0.0287163292291289],
#  ['Project Subject Subcategory Tree_College & Career Prep, Financial Literacy',
#   0.028657001397669433],
#  ['Project Subject Subcategory Tree_Social Sciences, Visual Arts',
#   0.028511500035182127],
#  ['Project Subject Subcategory Tree_Economics, Financial Literacy',
#   -0.0282102779224615],
#  ['Project Subject Subcategory Tree_ESL, History & Geography',
#   0.02800016263929736],
#  ['Project Subject Subcategory Tree_College & Career Prep, Parent Involvement',
#   -0.02797217031202549],
#  ['School State_Mississippi', -0.02748437033623347],
#  ['Project Subject Subcategory Tree_Extracurricular, Literature & Writing',
#   0.02617007353963521],
#  ['Project Subject Subcategory Tree_Other, Visual Arts', 0.02600694510316824],
#  ['Project Subject Subcategory Tree_Extracurricular, Other',
#   0.025872506929650305],
#  ['School Success Rate', -0.025776909203259216],
#  ['Project Subject Subcategory Tree_Economics, Literature & Writing',
#   0.02557531465735924],
#  ['Project Subject Subcategory Tree_Gym & Fitness, Health & Life Science',
#   0.025279784220352305]]

# %%
activated_features = {}
for feature in config.CATEGORICAL_COLS:
    activated_features[feature] = f"{feature}_{raw_data[raw_data['Project ID'] == '914ed5ecded471bcb3922ccf422d9265' ][feature].values[0]}"

# %%
max_activated_compactor = MaxNonActivatedCompactor(activated_features)

# %%
disagreement.compact_features(max_activated_compactor)

# %%
disagreement.get_disagreement(20, None)
# Out:
# {'feature_agreement': 0.95,
#  'rank_agreement': 0.2,
#  'sign_agreement': 0.7,
#  'signed_rank_agreement': 0.2}

# %%
disagreement.sorted_explanation1[:20]
# Out:
# [['School Success Rate', -0.02073560551451692],
#  ['Project Cost', -0.016155206447674573],
#  ['School City Success Rate', -0.007373891001113861],
#  ['School County Success Rate', -0.006529038491705706],
#  ['Project Resource Category', -0.006248685005766674],
#  ['Project Posted Month', 0.005906740663720029],
#  ['Teacher Project Posted Sequence', -0.004860845310354307],
#  ['Teacher Success Rate', 0.0041988864940344685],
#  ['School Percentage Free Lunch', -0.003522525960356688],
#  ['Teacher Success Rate Imputed', -0.002740343722766738],
#  ['School State', -0.0014524365215038415],
#  ['Teacher Prefix', 0.0014260352586097725],
#  ['Project Count in State', -0.000468491965712019],
#  ['Project Subject Category Tree', -0.0004492578398571823],
#  ['Project Grade Level Category', 0.0003245797966610553],
#  ['School City Success Rate Imputed', -0.00025017424301040594],
#  ['Project Subject Subcategory Tree', -0.00018697521085869084],
#  ['School Success Rate Imputed', -0.0001626017453008899],
#  ['School Metro Type', -0.00013262778791613527],
#  ['School County Success Rate Imputed', 0.0]]

# %%
disagreement.sorted_explanation2[:20]
# Out:
# [['School State', -0.039534328867710765],
#  ['Project Subject Subcategory Tree', 0.03927456784041016],
#  ['Project Subject Category Tree', 0.03567932952839871],
#  ['Project Cost', -0.02952929601923634],
#  ['School Success Rate', -0.025776909203259216],
#  ['Project Resource Category', -0.023836287905638617],
#  ['Project Type', -0.01503048269510653],
#  ['Teacher Success Rate', 0.012813475583557795],
#  ['Teacher Prefix', -0.009125173179515167],
#  ['Teacher Success Rate Imputed', -0.009009803255737941],
#  ['School Percentage Free Lunch', -0.008126922865584042],
#  ['School City Success Rate', -0.007641181462543814],
#  ['Teacher Project Posted Sequence', -0.0068610916964242825],
#  ['Project Posted Month', 0.006653825060046289],
#  ['School County Success Rate Imputed', -0.006001961298228468],
#  ['School City Success Rate Imputed', -0.005584178358922777],
#  ['School Metro Type', -0.0049755677668917855],
#  ['School Success Rate Imputed', -0.004736606280679097],
#  ['School County Success Rate', -0.004302345526877994],
#  ['Project Grade Level Category', -0.002102650708647841]]

# %% [markdown]
# #### All the metrics shows that there is significant disagreement for the first explanation
#
# Based on top 20 features in the first explanation of lime and treeshap
#
#
# Feature Agreement 0.15: The feature agreement score is 0.15. This indicates that the top 20 features in Lime's explanation are different from TreeSHAP's top 20 features.
#
# Rank Agreement 0.05: The rank agreement score is 0.05. This means that not only are the top 20 features different, but there is also a significant difference in the order of these features between Lime and TreeSHAP.
#
# Sign Agreement 0.15: The sign agreement score is 0.15. This suggests that the top 20 features in Lime's explanation have different features compared to TreeSHAP's top 20 features when considering the sign of the feature values.
#
# Signed Rank Agreement 0.05: The signed rank agreement score is 0.05. This implies that the top 20 features in Lime's explanation not only differ in terms of the features themselves but also in their rank and sign when compared to TreeSHAP's top 20 features.

# %%
from compactor.MaxNonActivatedCompactor import MaxNonActivatedCompactor
from compactor.MaxCompactor import MaxCompactor
from compactor.ActivatedCompactor import ActivatedCompactor

# %% [markdown]
# ## Function to calculate average Disgreement

# %%
def disagreement_average(explanations1: dict , explanations2: dict , k: int, features_F: list , method = None, raw_data = None, debug = False) -> dict:
    disagreement_mean = {'feature_agreement': 0.0,
     'rank_agreement': 0.0,
     'sign_agreement': 0.0,
     'signed_rank_agreement': 0.0}
    
    for project_id in explanations1.keys():
        if debug:
            print(f"******************Project ID: {project_id}************************")
        
        if len(explanations1[project_id]) < k:
            raise ValueError(f"K should be less than {len(explanations1[project_id])}")
        
        disagreement_calc_2 = Disagreement(explanations1[project_id], explanations2[project_id])
        
        if debug:
            print("Initial Explanation 1 \n",disagreement_calc_2.sorted_explanation1[:k])
            print("Initial Explanation 2 \n",disagreement_calc_2.sorted_explanation2[:k])
            
        if method=="max":
            max_compactor = MaxCompactor(config.CATEGORICAL_COLS)
            disagreement_calc_2.compact_features(max_compactor)
            
        elif method == "activated" and raw_data is not None:
            activated_features = {}
            for feature in config.CATEGORICAL_COLS:
                activated_features[feature] = f"{feature}_{raw_data[raw_data['Project ID'] == project_id ][feature].values[0]}"
            activated_compactor = ActivatedCompactor(activated_features)
            disagreement_calc_2.compact_features(activated_compactor)
            
        elif method == "maxnonactivated" and raw_data is not None:
            activated_features = {}
            for feature in config.CATEGORICAL_COLS:
                activated_features[feature] = f"{feature}_{raw_data[raw_data['Project ID'] == project_id ][feature].values[0]}"
            max_non_activated_compactor = MaxNonActivatedCompactor(activated_features)
            disagreement_calc_2.compact_features(max_non_activated_compactor)
            
        if debug:
            print("After Compact Explanation 1 \n",disagreement_calc_2.sorted_explanation1[:k])
            print("After Compact Explanation 2 \n",disagreement_calc_2.sorted_explanation2[:k])
            
        disagreement = disagreement_calc_2.get_disagreement(k, features_F)
        
        if debug:
            print("Disagreement : ", disagreement)
        
        for key in list(disagreement_mean.keys()):
            if disagreement[key] == None:
                raise ValueError(f"The value for key '{key}' in disagreement_mean is None.")
            disagreement_mean[key] += disagreement[key]
        
        if debug:
            print("****************************************")

    for key in list(disagreement_mean.keys()):
        disagreement_mean[key] = round(disagreement_mean[key] / len(explanations1.keys()),3)
    
    if debug:
        print("*********************************************")
        print(disagreement_mean)
        print("*********************************************")

    
    return disagreement_mean

# %%
def disgreement_mean_across__top_500(explanations, k_range, method=None, raw_data=None, debug=False):
    disgreement_mean_across__top_500_various_k = {'feature_agreement': [],
         'rank_agreement': [],
         'sign_agreement': [],
         'signed_rank_agreement': []}


    for i in range(1,k_range,1):
        explanations_lime = disagreement_average(explanations["fold0"]["lime"]["top"], explanations["fold0"]["treeshap"]["top"], i, None, method, raw_data,  debug)

        for key in list(disgreement_mean_across__top_500_various_k.keys()):
            disgreement_mean_across__top_500_various_k[key].append(explanations_lime[key])



    disgreement_mean_across__bottom_500_various_k = {'feature_agreement': [],
         'rank_agreement': [],
         'sign_agreement': [],
         'signed_rank_agreement': []}

    for i in range(1,k_range,1):
        explanations_lime = disagreement_average(explanations["fold0"]["lime"]["bottom"], explanations["fold0"]["treeshap"]["bottom"], i, None,method, raw_data, debug)

        for key in list(disgreement_mean_across__bottom_500_various_k.keys()):
            disgreement_mean_across__bottom_500_various_k[key].append(explanations_lime[key])
            
    return disgreement_mean_across__top_500_various_k, disgreement_mean_across__bottom_500_various_k

# %%
def disgreement_mean_at_k(explanations, k, method=None, raw_data=None, debug=True):
    

    disgreement_mean_across__top_500_at_k = disagreement_average(explanations["fold0"]["lime"]["top"], explanations["fold0"]["treeshap"]["top"], k, None,method, raw_data, debug)

    disgreement_mean_across__bottom_500_various_k = disagreement_average(explanations["fold0"]["lime"]["bottom"], explanations["fold0"]["treeshap"]["bottom"], k, None,method, raw_data, debug)

    return disgreement_mean_across__top_500_at_k, disgreement_mean_across__bottom_500_various_k

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
def plot_average_accross_n_projects_various_k_features(disgreement_mean_across__top_n_various_k, disgreement_mean_across__bottom_n_various_k, feature_n):

    feature_range = range(1, feature_n, 1)
    feature_agreement_top = disgreement_mean_across__top_n_various_k["feature_agreement"]
    rank_agreement_top = disgreement_mean_across__top_n_various_k["rank_agreement"]
    sign_agreement_top = disgreement_mean_across__top_n_various_k["sign_agreement"]
    signed_rank_agreement_top = disgreement_mean_across__top_n_various_k["signed_rank_agreement"]


    feature_agreement_bottom = disgreement_mean_across__bottom_n_various_k["feature_agreement"]
    rank_agreement_bottom = disgreement_mean_across__bottom_n_various_k["rank_agreement"]
    sign_agreement_bottom = disgreement_mean_across__bottom_n_various_k["sign_agreement"]
    signed_rank_agreement_bottom = disgreement_mean_across__bottom_n_various_k["signed_rank_agreement"]


    # Create separate subplots for each agreement metric
    fig, axs = plt.subplots(4, 1, figsize=(10, 16))

    # Plot Feature Agreement for top k
    axs[0].plot(feature_range, feature_agreement_top, label='Feature Agreement (Top 500)', marker='o', color='b')
    axs[0].plot(feature_range, feature_agreement_bottom, label='Feature Agreement (Bottom 500)', linestyle='--', marker='o', color='r')
    axs[0].set_xlabel('Number of Features (Top K)')
    axs[0].set_ylabel('Agreement Score')
    axs[0].set_title('Feature Agreement vs. Number of Features (Top K)')
    axs[0].legend()
    axs[0].grid(True)

    # Plot Rank Agreement for top k
    axs[1].plot(feature_range, rank_agreement_top, label='Rank Agreement (Top 500)', marker='s', color='g')
    axs[1].plot(feature_range, rank_agreement_bottom, label='Rank Agreement (Bottom 500)', linestyle='--', marker='s', color='m')
    axs[1].set_xlabel('Number of Features (Top K)')
    axs[1].set_ylabel('Agreement Score')
    axs[1].set_title('Rank Agreement vs. Number of Features (Top K)')
    axs[1].legend()
    axs[1].grid(True)

    # Plot Sign Agreement for top k
    axs[2].plot(feature_range, sign_agreement_top, label='Sign Agreement (Top 500)', marker='^', color='c')
    axs[2].plot(feature_range, sign_agreement_bottom, label='Sign Agreement (Bottom 500)', linestyle='--', marker='^', color='y')
    axs[2].set_xlabel('Number of Features (Top K)')
    axs[2].set_ylabel('Agreement Score')
    axs[2].set_title('Sign Agreement vs. Number of Features (Top K)')
    axs[2].legend()
    axs[2].grid(True)

    # Plot Signed Rank Agreement for top k
    axs[3].plot(feature_range, signed_rank_agreement_top, label='Signed Rank Agreement (Top 500)', marker='x', color='k')
    axs[3].plot(feature_range, signed_rank_agreement_bottom, label='Signed Rank Agreement (Bottom 500)', linestyle='--', marker='x', color='orange')
    axs[3].set_xlabel('Number of Features (Top K)')
    axs[3].set_ylabel('Agreement Score')
    axs[3].set_title('Signed Rank Agreement vs. Number of Features (Top K)')
    axs[3].legend()
    axs[3].grid(True)

    # Adjust spacing between subplots
    plt.tight_layout()

    # Show the plots
    plt.show()
#     plt.savefig("test.png")

# %%
disgreement_ mean_across__top_500_various_k , disgreement_mean_across__bottom_500_various_k = disgreement_mean_across__top_500(explanations, 576)

# %%
plot_average_accross_n_projects_various_k_features(disgreement_mean_across__top_500_various_k , disgreement_mean_across__bottom_500_various_k,576)

# %%
disgreement_mean_across__top_500_various_k_max , disgreement_mean_across__bottom_500_various_max = disgreement_mean_across__top_500(explanations, 20, "max", raw_data)

# %%
plot_average_accross_n_projects_various_k_features(disgreement_mean_across__top_500_various_k_max , disgreement_mean_across__bottom_500_various_max,20)

# %%
disgreement_mean_across__top_500_various_k_max , disgreement_mean_across__bottom_500_various_max = disgreement_mean_across__top_500(explanations, 20, "activated", raw_data)
plot_average_accross_n_projects_various_k_features(disgreement_mean_across__top_500_various_k_max , disgreement_mean_across__bottom_500_various_max,20)

# %%
disgreement_mean_across__top_500_various_k_max , disgreement_mean_across__bottom_500_various_max = disgreement_mean_across__top_500(explanations, 20, "maxnonactivated", raw_data)
plot_average_accross_n_projects_various_k_features(disgreement_mean_across__top_500_various_k_max , disgreement_mean_across__bottom_500_various_max,20)

# %% [markdown]
# ## 20% features

# %%
top , bottom = disgreement_mean_at_k(explanations, 4, method="max", raw_data=raw_data)
# Out:
# *********************************Project ID: cdc83b2eb031d999c123535bf09d24a0***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05828515065993562], ['School State_New Mexico', -0.04561995832431883], ['Project Subject Subcategory Tree_Mathematics, Performing Arts', -0.03652875725130923], ['School State_Mississippi', 0.03525123751671513]]
# Initial Explanation 2
#  [['Project Cost', 0.05714906222884565], ['School State_Mississippi', 0.041025607910487455], ['Project Resource Category_Technology', 0.022928445398821395], ['Teacher Project Posted Sequence', 0.017752762721138425]]
# After Compact Explanation 1
#  [['Project Cost', 0.05828515065993562], ['School State', -0.04561995832431883], ['Project Subject Subcategory Tree', -0.03652875725130923], ['Project Resource Category', 0.02412976165593627]]
# After Compact Explanation 2
#  [['Project Cost', 0.05714906222884565], ['School State', 0.041025607910487455], ['Project Resource Category', 0.022928445398821395], ['Teacher Project Posted Sequence', 0.017752762721138425]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.5, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 203c08ca3b1e42a9ba07c93eac4c20cc***********************************
# Initial Explanation 1
#  [['Project Cost', 0.057798666154747505], ['School State_New Mexico', -0.04301231875416275], ['Project Subject Subcategory Tree_ESL, History & Geography', -0.03690086300243074], ['School State_Mississippi', -0.03358817742207904]]
# Initial Explanation 2
#  [['Project Cost', 0.04720200023687084], ['School State_Nebraska', 0.03180983088559515], ['Teacher Project Posted Sequence', 0.02116222924447584], ['Project Resource Category_Technology', 0.017711678433863655]]
# After Compact Explanation 1
#  [['Project Cost', 0.057798666154747505], ['School State', -0.04301231875416275], ['Project Subject Subcategory Tree', -0.03690086300243074], ['Project Resource Category', 0.022769771695808697]]
# After Compact Explanation 2
#  [['Project Cost', 0.04720200023687084], ['School State', 0.03180983088559515], ['Teacher Project Posted Sequence', 0.02116222924447584], ['Project Resource Category', 0.017711678433863655]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.75, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.5}
# ********************************************************************
# *********************************Project ID: d1fb6298685f8afb718cc48543e2e244***********************************
# Initial Explanation 1
#  [['Project Cost', 0.057679254446686895], ['School State_Mississippi', 0.03747080592949012], ['School State_New Mexico', -0.03514193119503172], ['School State_Oregon', 0.034152587860776164]]
# Initial Explanation 2
#  [['Project Cost', 0.04977401685570612], ['School State_Mississippi', 0.037898016106146314], ['Project Resource Category_Technology', 0.02313444182741705], ['School City Success Rate', 0.018317078838890666]]
# After Compact Explanation 1
#  [['Project Cost', 0.057679254446686895], ['School State', 0.03747080592949012], ['Project Subject Subcategory Tree', -0.03328361337941619], ['Project Type', -0.024943255087479087]]
# After Compact Explanation 2
#  [['Project Cost', 0.04977401685570612], ['School State', 0.037898016106146314], ['Project Resource Category', 0.02313444182741705], ['School City Success Rate', 0.018317078838890666]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.5, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.5}
# ********************************************************************
# *********************************Project ID: a2d940be8dc020e99c4f23fa979994bf***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05782109656720192], ['Project Subject Subcategory Tree_Applied Sciences, Social Sciences', -0.04282837845521033], ['School State_New Mexico', -0.03721475964343904], ['Project Subject Subcategory Tree_Extracurricular, Other', -0.03302505173641548]]
# Initial Explanation 2
#  [['Project Cost', 0.05154882478584341], ['School State_Missouri', 0.02442075636919526], ['Project Resource Category_Technology', 0.019200101020205692], ['Teacher Project Posted Sequence', 0.01768463877403292]]
# After Compact Explanation 1
#  [['Project Cost', 0.05782109656720192], ['Project Subject Subcategory Tree', -0.04282837845521033], ['School State', -0.03721475964343904], ['Project Resource Category', 0.02248825936823773]]
# After Compact Explanation 2
#  [['Project Cost', 0.05154882478584341], ['School State', 0.02442075636919526], ['Project Resource Category', 0.019200101020205692], ['Teacher Project Posted Sequence', 0.01768463877403292]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.25, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: f82498e55e15c90643967f8a38ddd98c***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05865340593618199], ['School State_New Mexico', -0.04449983051795489], ['Project Subject Subcategory Tree_ESL, Health & Life Science', -0.0371454299738385], ['Project Subject Subcategory Tree_Performing Arts, Special Needs', 0.033211037655462246]]
# Initial Explanation 2
#  [['Project Cost', 0.051558824788646686], ['School State_Missouri', 0.02442075636919526], ['Project Resource Category_Technology', 0.019200101020205692], ['Teacher Project Posted Sequence', 0.017674389803312353]]
# After Compact Explanation 1
#  [['Project Cost', 0.05865340593618199], ['School State', -0.04449983051795489], ['Project Subject Subcategory Tree', -0.0371454299738385], ['Project Resource Category', 0.024594922596660164]]
# After Compact Explanation 2
#  [['Project Cost', 0.051558824788646686], ['School State', 0.02442075636919526], ['Project Resource Category', 0.019200101020205692], ['Teacher Project Posted Sequence', 0.017674389803312353]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.5, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 53421ba867de46ff359de40e9753711e***********************************
# Initial Explanation 1
#  [['Project Cost', 0.0563224269876776], ['School State_New Mexico', -0.046005162526293594], ['School State_Oregon', 0.03830315306337161], ['School State_Mississippi', 0.037810243936383575]]
# Initial Explanation 2
#  [['Project Cost', 0.052307260882253105], ['School State_Mississippi', 0.0422700350210016], ['Project Resource Category_Technology', 0.022385058963836853], ['School City Success Rate', 0.016162650736459908]]
# After Compact Explanation 1
#  [['Project Cost', 0.0563224269876776], ['School State', -0.046005162526293594], ['Project Subject Subcategory Tree', -0.02966105464166279], ['Project Type', -0.02501129988726566]]
# After Compact Explanation 2
#  [['Project Cost', 0.052307260882253105], ['School State', 0.0422700350210016], ['Project Resource Category', 0.022385058963836853], ['School City Success Rate', 0.016162650736459908]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.5, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 4b972ebb44d4ffc7516c8ff160301ef3***********************************
# Initial Explanation 1
#  [['Project Cost', 0.058200278509269655], ['School State_Oregon', 0.037624612682239524], ['School State_New Mexico', -0.036511470335721705], ['School State_Nebraska', -0.03286604456771381]]
# Initial Explanation 2
#  [['School State_Mississippi', 0.04184519403625018], ['Project Cost', 0.025001699409003778], ['Project Resource Category_Technology', 0.019581868575152157], ['Teacher Project Posted Sequence', 0.018822313698356085]]
# After Compact Explanation 1
#  [['Project Cost', 0.058200278509269655], ['School State', 0.037624612682239524], ['Project Subject Subcategory Tree', -0.030437929210460866], ['Project Resource Category', 0.023379325898719463]]
# After Compact Explanation 2
#  [['School State', 0.04184519403625018], ['Project Cost', 0.025001699409003778], ['Project Resource Category', 0.019581868575152157], ['Teacher Project Posted Sequence', 0.018822313698356085]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.0, 'sign_agreement': 0.75, 'signed_rank_agreement': 0.0}
# ********************************************************************
# *********************************Project ID: 243ac2a985a19d4df09c21541494dcae***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05672953743292205], ['School State_New Mexico', -0.03506857062557912], ['School State_Mississippi', -0.02981207452713723], ['Project Subject Subcategory Tree_Applied Sciences, Economics', -0.02971048116611941]]
# Initial Explanation 2
#  [['Project Cost', 0.05032960327702767], ['School State_Nebraska', 0.03125864807265316], ['Teacher Project Posted Sequence', 0.021794702131160193], ['Project Resource Category_Technology', 0.016631714216516685]]
# After Compact Explanation 1
#  [['Project Cost', 0.05672953743292205], ['School State', -0.03506857062557912], ['Project Subject Subcategory Tree', -0.02971048116611941], ['Project Resource Category', 0.024152158219214123]]
# After Compact Explanation 2
#  [['Project Cost', 0.05032960327702767], ['School State', 0.03125864807265316], ['Teacher Project Posted Sequence', 0.021794702131160193], ['Project Resource Category', 0.016631714216516685]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.75, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.5}
# ********************************************************************
# *********************************Project ID: d1715d9dc331bee79ee781ff26684f8f***********************************
# Initial Explanation 1
#  [['Project Cost', 0.057479671734858656], ['School State_New Mexico', -0.04738158100976737], ['School State_Mississippi', -0.043008711705219346], ['Project Subject Category Tree_Literacy & Language, Health & Sports', -0.031180815280753747]]
# Initial Explanation 2
#  [['Project Cost', 0.05561650296623611], ['Project Resource Category_Technology', 0.01831125229417239], ['School State_Nevada', 0.01728138727323085], ['School City Success Rate', 0.015411783625554563]]
# After Compact Explanation 1
#  [['Project Cost', 0.057479671734858656], ['School State', -0.04738158100976737], ['Project Subject Category Tree', -0.031180815280753747], ['Project Subject Subcategory Tree', 0.030889147613611792]]
# After Compact Explanation 2
#  [['Project Cost', 0.05561650296623611], ['Project Resource Category', 0.01831125229417239], ['School State', 0.01728138727323085], ['School City Success Rate', 0.015411783625554563]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.25, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 6e87bf75a7ec7e474e90aef4188a7007***********************************
# Initial Explanation 1
#  [['Project Cost', 0.056579863206165724], ['School State_New Mexico', -0.038320962087577744], ['School State_Mississippi', 0.03366882837066851], ['School State_Oregon', 0.031049871031684505]]
# Initial Explanation 2
#  [['Project Cost', 0.05557974306796723], ['School State_Mississippi', 0.04443751283152324], ['Project Resource Category_Technology', 0.024440182325379284], ['School City Success Rate', 0.014749500249704397]]
# After Compact Explanation 1
#  [['Project Cost', 0.056579863206165724], ['School State', -0.038320962087577744], ['Project Subject Subcategory Tree', -0.03019754838907455], ['Project Resource Category', 0.023859846481105517]]
# After Compact Explanation 2
#  [['Project Cost', 0.05557974306796723], ['School State', 0.04443751283152324], ['Project Resource Category', 0.024440182325379284], ['School City Success Rate', 0.014749500249704397]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.5, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 269ee45ecaf3d049dc0ed152cb8cd455***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05643334183811617], ['School State_Mississippi', -0.04372177480604676], ['School State_Oregon', 0.03501452655536818], ['Project Subject Subcategory Tree_Economics, Environmental Science', -0.03418450763142528]]
# Initial Explanation 2
#  [['Project Cost', 0.043217754838092336], ['School State_Nebraska', 0.040977806031041834], ['Teacher Project Posted Sequence', 0.022389710752706835], ['School City Success Rate', 0.01637194786701002]]
# After Compact Explanation 1
#  [['Project Cost', 0.05643334183811617], ['School State', -0.04372177480604676], ['Project Subject Subcategory Tree', -0.03418450763142528], ['Project Resource Category', -0.023354669538044163]]
# After Compact Explanation 2
#  [['Project Cost', 0.043217754838092336], ['School State', 0.040977806031041834], ['Teacher Project Posted Sequence', 0.022389710752706835], ['School City Success Rate', 0.01637194786701002]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.5, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: d8c2ee2bd0b3552656e4db4908a6b09b***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05796286517271961], ['School State_Nebraska', -0.03526821469835562], ['School State_Mississippi', -0.034546688640871875], ['School State_New Mexico', -0.03136639173949492]]
# Initial Explanation 2
#  [['Project Cost', 0.049644932920823524], ['Project Resource Category_Technology', 0.017972713267212725], ['School State_Nevada', 0.017922158847877654], ['Teacher Project Posted Sequence', 0.016898019621651203]]
# After Compact Explanation 1
#  [['Project Cost', 0.05796286517271961], ['School State', -0.03526821469835562], ['Project Subject Subcategory Tree', 0.026739583318447904], ['Project Resource Category', 0.022475275685093134]]
# After Compact Explanation 2
#  [['Project Cost', 0.049644932920823524], ['Project Resource Category', 0.017972713267212725], ['School State', 0.017922158847877654], ['Teacher Project Posted Sequence', 0.016898019621651203]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.25, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: bef88155e439801648114a3b663483e6***********************************
# Initial Explanation 1
#  [['Project Cost', 0.057978328342301454], ['School State_New Mexico', -0.038013762673120045], ['Project Subject Subcategory Tree_Character Education, Other', -0.03702426624811797], ['School State_Oregon', 0.036740881745922584]]
# Initial Explanation 2
#  [['Project Cost', 0.04979575360204308], ['School State_Mississippi', 0.04050002376409338], ['Project Resource Category_Technology', 0.02361329109520739], ['School Success Rate', 0.013384857475011813]]
# After Compact Explanation 1
#  [['Project Cost', 0.057978328342301454], ['School State', -0.038013762673120045], ['Project Subject Subcategory Tree', -0.03702426624811797], ['Project Type', -0.029508165317130575]]
# After Compact Explanation 2
#  [['Project Cost', 0.04979575360204308], ['School State', 0.04050002376409338], ['Project Resource Category', 0.02361329109520739], ['School Success Rate', 0.013384857475011813]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.5, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: a23857ddb64f6f31d2d89b469f1f5045***********************************
# Initial Explanation 1
#  [['Project Subject Subcategory Tree_ESL, Social Sciences', -0.049624168531690716], ['Project Subject Subcategory Tree_Music, Social Sciences', -0.04791093944567183], ['Project Subject Subcategory Tree_Character Education, Gym & Fitness', -0.040247517771444606], ['Project Subject Subcategory Tree_Environmental Science, Social Sciences', -0.03800115175957171]]
# Initial Explanation 2
#  [['School State_Mississippi', 0.05196585860313462], ['Project Resource Category_Technology', 0.02266978082314722], ['Project Cost', 0.018694953408476066], ['School City Success Rate', 0.016476252601021316]]
# After Compact Explanation 1
#  [['Project Subject Subcategory Tree', -0.049624168531690716], ['School State', 0.031606787035318565], ['Project Resource Category', 0.022643247687498057], ['Project Type', -0.022346085550668384]]
# After Compact Explanation 2
#  [['School State', 0.05196585860313462], ['Project Resource Category', 0.02266978082314722], ['Project Cost', 0.018694953408476066], ['School City Success Rate', 0.016476252601021316]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.0, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.0}
# ********************************************************************
# *********************************Project ID: 28d8a4a51fffde7b38d3347999a076a5***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05748371967420547], ['School State_New Mexico', -0.04271077096737831], ['School State_Mississippi', 0.03696950170732853], ['Project Subject Subcategory Tree_Early Development, Health & Life Science', -0.035135956588076486]]
# Initial Explanation 2
#  [['Project Cost', 0.050168631318779265], ['School State_Mississippi', 0.046197782999634], ['Project Resource Category_Technology', 0.022959913244294514], ['School City Success Rate', 0.013543128429892021]]
# After Compact Explanation 1
#  [['Project Cost', 0.05748371967420547], ['School State', -0.04271077096737831], ['Project Subject Subcategory Tree', -0.035135956588076486], ['Teacher Prefix', -0.031167212377466804]]
# After Compact Explanation 2
#  [['Project Cost', 0.050168631318779265], ['School State', 0.046197782999634], ['Project Resource Category', 0.022959913244294514], ['School City Success Rate', 0.013543128429892021]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.5, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: bc85b4439d454a518b64da36cbe2dafb***********************************
# Initial Explanation 1
#  [['Project Subject Subcategory Tree_Mathematics, Team Sports', 0.042537297864499266], ['Project Subject Subcategory Tree_Health & Life Science, Nutrition Education', 0.04138525688433245], ['School State_Mississippi', 0.036005988698746015], ['School State_New Mexico', -0.035269282080725814]]
# Initial Explanation 2
#  [['School State_Mississippi', 0.03994129294803315], ['Project Resource Category_Technology', 0.02019933045972948], ['Project Cost', 0.018857761817055233], ['School City Success Rate', 0.016676019089138662]]
# After Compact Explanation 1
#  [['Project Subject Subcategory Tree', 0.042537297864499266], ['School State', 0.036005988698746015], ['Project Subject Category Tree', 0.03388489618786802], ['Project Type', -0.031073184572776594]]
# After Compact Explanation 2
#  [['School State', 0.03994129294803315], ['Project Resource Category', 0.02019933045972948], ['Project Cost', 0.018857761817055233], ['School City Success Rate', 0.016676019089138662]]
# Disagreement :  {'feature_agreement': 0.25, 'rank_agreement': 0.0, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.0}
# ********************************************************************
# *********************************Project ID: 3ec6f790c04a3f524730a7ae5e1dc162***********************************
# Initial Explanation 1
#  [['Project Cost', 0.057093475755560834], ['Project Subject Subcategory Tree_ESL, History & Geography', 0.03746856611647125], ['School State_New Mexico', -0.03678430682812522], ['Project Subject Subcategory Tree_Health & Life Science, Parent Involvement', -0.03547409489827585]]
# Initial Explanation 2
#  [['Project Cost', 0.04949933709173138], ['School State_Mississippi', 0.04198834205464209], ['Project Resource Category_Technology', 0.02245425955558858], ['School Success Rate', 0.013801399295255123]]
# After Compact Explanation 1
#  [['Project Cost', 0.057093475755560834], ['Project Subject Subcategory Tree', 0.03746856611647125], ['School State', -0.03678430682812522], ['Project Type', -0.02780550660699061]]
# After Compact Explanation 2
#  [['Project Cost', 0.04949933709173138], ['School State', 0.04198834205464209], ['Project Resource Category', 0.02245425955558858], ['School Success Rate', 0.013801399295255123]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.25, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: c522a6bcc021348e5b129dfec342fb16***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05668700772552516], ['School State_New Mexico', -0.04501068353493454], ['Project Subject Subcategory Tree_Parent Involvement', -0.03664848496349483], ['School State_Oregon', 0.035974937907009764]]
# Initial Explanation 2
#  [['Project Cost', 0.04288347303777755], ['School State_Nebraska', 0.03906234024218065], ['Teacher Project Posted Sequence', 0.0220398655178019], ['School Success Rate', 0.01635595093489428]]
# After Compact Explanation 1
#  [['Project Cost', 0.05668700772552516], ['School State', -0.04501068353493454], ['Project Subject Subcategory Tree', -0.03664848496349483], ['Project Resource Category', -0.02393514920033771]]
# After Compact Explanation 2
#  [['Project Cost', 0.04288347303777755], ['School State', 0.03906234024218065], ['Teacher Project Posted Sequence', 0.0220398655178019], ['School Success Rate', 0.01635595093489428]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.5, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 0c432a52445eedd0d08c7dafddfca82a***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05799954544061304], ['School State_Oregon', 0.03696783184112866], ['Project Subject Subcategory Tree_Early Development, Health & Life Science', -0.03512879502476552], ['Project Subject Subcategory Tree_Civics & Government, Performing Arts', -0.034572895945889665]]
# Initial Explanation 2
#  [['Project Cost', 0.05482743123534874], ['School State_Mississippi', 0.03392381752715665], ['Project Resource Category_Technology', 0.022327185185374673], ['Teacher Project Posted Sequence', 0.012304619799656392]]
# After Compact Explanation 1
#  [['Project Cost', 0.05799954544061304], ['School State', 0.03696783184112866], ['Project Subject Subcategory Tree', -0.03512879502476552], ['Project Type', -0.025525985350757622]]
# After Compact Explanation 2
#  [['Project Cost', 0.05482743123534874], ['School State', 0.03392381752715665], ['Project Resource Category', 0.022327185185374673], ['Teacher Project Posted Sequence', 0.012304619799656392]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.5, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.5}
# ********************************************************************
# *********************************Project ID: 031d0b999298263ef534867289be65cb***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05707098222212264], ['School State_New Mexico', -0.03803430248755611], ['Project Subject Subcategory Tree_Economics, Mathematics', -0.03677139592590146], ['School State_Oregon', 0.033499377233866964]]
# Initial Explanation 2
#  [['Project Cost', 0.04140629195823749], ['Project Resource Category_Technology', 0.01920141651699396], ['Teacher Project Posted Sequence', 0.018206762721292763], ['School City Success Rate', 0.01639297808428182]]
# After Compact Explanation 1
#  [['Project Cost', 0.05707098222212264], ['School State', -0.03803430248755611], ['Project Subject Subcategory Tree', -0.03677139592590146], ['Project Resource Category', 0.023084385152271028]]
# After Compact Explanation 2
#  [['Project Cost', 0.04140629195823749], ['Project Resource Category', 0.01920141651699396], ['Teacher Project Posted Sequence', 0.018206762721292763], ['School City Success Rate', 0.01639297808428182]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.25, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 732ca3d502f78631da39219542e1baf3***********************************
# Initial Explanation 1
#  [['Project Cost', 0.0578187904800649], ['School State_New Mexico', -0.04462143717508763], ['School State_Nebraska', -0.0370740838370119], ['School State_Mississippi', 0.03338913297110677]]
# Initial Explanation 2
#  [['Project Cost', 0.04922965060279466], ['School State_Mississippi', 0.03955320283004312], ['Project Resource Category_Technology', 0.02426291197712544], ['School Success Rate', 0.014624874734847708]]
# After Compact Explanation 1
#  [['Project Cost', 0.0578187904800649], ['School State', -0.04462143717508763], ['Project Subject Subcategory Tree', -0.031613371266586594], ['Project Type', -0.02517454061200808]]
# After Compact Explanation 2
#  [['Project Cost', 0.04922965060279466], ['School State', 0.03955320283004312], ['Project Resource Category', 0.02426291197712544], ['School Success Rate', 0.014624874734847708]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.5, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: ba0e683d4fea6d716351df6c9a95999a***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05666290550622853], ['School State_Oregon', 0.037622328469575285], ['School State_New Mexico', -0.036954061224298757], ['School State_Mississippi', -0.033268574799328904]]
# Initial Explanation 2
#  [['Project Cost', 0.0497697294664431], ['Project Resource Category_Technology', 0.019425486052587076], ['School State_Nevada', 0.01727261794806509], ['Teacher Project Posted Sequence', 0.01564802257639485]]
# After Compact Explanation 1
#  [['Project Cost', 0.05666290550622853], ['School State', 0.037622328469575285], ['Project Subject Subcategory Tree', 0.032749401263299775], ['Project Resource Category', 0.024532442861464346]]
# After Compact Explanation 2
#  [['Project Cost', 0.0497697294664431], ['Project Resource Category', 0.019425486052587076], ['School State', 0.01727261794806509], ['Teacher Project Posted Sequence', 0.01564802257639485]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.25, 'sign_agreement': 0.75, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 6d76162617df823cf701af480fc82d7d***********************************
# Initial Explanation 1
#  [['School State_New Mexico', -0.04635629363481144], ['Project Subject Subcategory Tree_College & Career Prep, Parent Involvement', -0.04244556924888118], ['Project Subject Subcategory Tree_Applied Sciences, Early Development', -0.04131049535769772], ['Project Subject Subcategory Tree_Health & Life Science, Health & Wellness', -0.04005796195364346]]
# Initial Explanation 2
#  [['School State_Nebraska', 0.0344078517386788], ['Teacher Project Posted Sequence', 0.020948249649934497], ['School Success Rate', 0.017221882387734696], ['Project Cost', 0.016710708238797452]]
# After Compact Explanation 1
#  [['School State', -0.04635629363481144], ['Project Subject Subcategory Tree', -0.04244556924888118], ['Project Subject Category Tree', -0.02799194116972908], ['Project Resource Category', 0.024553711637907]]
# After Compact Explanation 2
#  [['School State', 0.0344078517386788], ['Teacher Project Posted Sequence', 0.020948249649934497], ['School Success Rate', 0.017221882387734696], ['Project Cost', 0.016710708238797452]]
# Disagreement :  {'feature_agreement': 0.25, 'rank_agreement': 0.25, 'sign_agreement': 0.0, 'signed_rank_agreement': 0.0}
# ********************************************************************
# *********************************Project ID: 398ebf5ab1710f633c9970fbfc5676a1***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05822675278707906], ['School State_Mississippi', -0.03881536043469812], ['School State_New Mexico', -0.032566452094718736], ['Project Subject Subcategory Tree_Health & Life Science, Nutrition Education', -0.02976395876509816]]
# Initial Explanation 2
#  [['Project Cost', 0.053847693978909775], ['Project Resource Category_Technology', 0.019398706154905767], ['School State_Nevada', 0.017889721835633737], ['Teacher Project Posted Sequence', 0.01542612315304723]]
# After Compact Explanation 1
#  [['Project Cost', 0.05822675278707906], ['School State', -0.03881536043469812], ['Project Subject Subcategory Tree', -0.02976395876509816], ['Project Type', -0.027270376229460262]]
# After Compact Explanation 2
#  [['Project Cost', 0.053847693978909775], ['Project Resource Category', 0.019398706154905767], ['School State', 0.017889721835633737], ['Teacher Project Posted Sequence', 0.01542612315304723]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.25, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 2cdfc223b61b41fb6f45941f5b9b26d8***********************************
# Initial Explanation 1
#  [['Project Cost', 0.057303154276427716], ['School State_Mississippi', -0.03858348372961866], ['School State_New Mexico', -0.035682193922485464], ['School State_Oregon', 0.030383139278350988]]
# Initial Explanation 2
#  [['Project Cost', 0.055673148913947444], ['Project Resource Category_Technology', 0.02060593230016309], ['Teacher Project Posted Sequence', 0.017553782047541516], ['School City Success Rate', 0.01640095510422725]]
# After Compact Explanation 1
#  [['Project Cost', 0.057303154276427716], ['School State', -0.03858348372961866], ['Project Subject Subcategory Tree', -0.028610204919662943], ['Project Type', -0.024997433284660493]]
# After Compact Explanation 2
#  [['Project Cost', 0.055673148913947444], ['Project Resource Category', 0.02060593230016309], ['Teacher Project Posted Sequence', 0.017553782047541516], ['School City Success Rate', 0.01640095510422725]]
# Disagreement :  {'feature_agreement': 0.25, 'rank_agreement': 0.25, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 8f5722aee4a6c2f4450c795ae36fda91***********************************
# Initial Explanation 1
#  [['Project Cost', 0.058410537083594324], ['School State_New Mexico', -0.04100764547421448], ['School State_Mississippi', 0.03852551224403768], ['School State_Oregon', 0.03317841159724942]]
# Initial Explanation 2
#  [['Project Cost', 0.05035337998460363], ['School State_Mississippi', 0.04402859858397278], ['Project Resource Category_Technology', 0.02417748655617743], ['School Success Rate', 0.013468082341237277]]
# After Compact Explanation 1
#  [['Project Cost', 0.058410537083594324], ['School State', -0.04100764547421448], ['Project Subject Subcategory Tree', -0.0259287038562672], ['Project Resource Category', 0.02411567557569289]]
# After Compact Explanation 2
#  [['Project Cost', 0.05035337998460363], ['School State', 0.04402859858397278], ['Project Resource Category', 0.02417748655617743], ['School Success Rate', 0.013468082341237277]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.5, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 73865bf39fe142f16dbde248f10a545a***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05805592928141925], ['Project Subject Subcategory Tree_Early Development, Gym & Fitness', -0.03474979341694866], ['School State_Oregon', 0.03301258591325618], ['School State_New Mexico', -0.032401313104304386]]
# Initial Explanation 2
#  [['Project Cost', 0.05372144532148923], ['Project Resource Category_Technology', 0.022520649188085714], ['Teacher Project Posted Sequence', 0.01738402724131447], ['School City Success Rate', 0.01604507414595446]]
# After Compact Explanation 1
#  [['Project Cost', 0.05805592928141925], ['Project Subject Subcategory Tree', -0.03474979341694866], ['School State', 0.03301258591325618], ['Project Resource Category', 0.023822179065175482]]
# After Compact Explanation 2
#  [['Project Cost', 0.05372144532148923], ['Project Resource Category', 0.022520649188085714], ['Teacher Project Posted Sequence', 0.01738402724131447], ['School City Success Rate', 0.01604507414595446]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.25, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 320737935858ae121039be94a787bf2a***********************************
# Initial Explanation 1
#  [['Project Cost', 0.057527638360477355], ['School State_Mississippi', -0.03568033157548521], ['School State_New Mexico', -0.03458919448306167], ['School State_Oregon', 0.031495764045283973]]
# Initial Explanation 2
#  [['Project Cost', 0.04078443026775403], ['School State_Nebraska', 0.03687912604103985], ['Teacher Project Posted Sequence', 0.021632763779437028], ['School Success Rate', 0.016512811612255974]]
# After Compact Explanation 1
#  [['Project Cost', 0.057527638360477355], ['School State', -0.03568033157548521], ['Project Subject Subcategory Tree', -0.02907496903717136], ['Project Subject Category Tree', 0.025248766356660412]]
# After Compact Explanation 2
#  [['Project Cost', 0.04078443026775403], ['School State', 0.03687912604103985], ['Teacher Project Posted Sequence', 0.021632763779437028], ['School Success Rate', 0.016512811612255974]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.5, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: d4d8582a00a3bd2bc18d670a9fd0931a***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05709445131366433], ['School State_New Mexico', -0.04511455065642216], ['School State_Mississippi', 0.029023432382543794], ['School State_Nebraska', -0.028479815397327725]]
# Initial Explanation 2
#  [['Project Cost', 0.04932435219990793], ['School State_Mississippi', 0.03898253320398453], ['Project Resource Category_Technology', 0.023636606206605393], ['School Success Rate', 0.014013784279136417]]
# After Compact Explanation 1
#  [['Project Cost', 0.05709445131366433], ['School State', -0.04511455065642216], ['Project Subject Subcategory Tree', -0.027992837006751373], ['Project Subject Category Tree', -0.026670593762641002]]
# After Compact Explanation 2
#  [['Project Cost', 0.04932435219990793], ['School State', 0.03898253320398453], ['Project Resource Category', 0.023636606206605393], ['School Success Rate', 0.014013784279136417]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.5, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 0415372f65a4fe6c71e72ff024e21a80***********************************
# Initial Explanation 1
#  [['Project Cost', 0.056724531967839026], ['School State_New Mexico', -0.0357473257516693], ['Project Subject Subcategory Tree_Early Development, Parent Involvement', -0.03484823039539686], ['Project Subject Subcategory Tree_Community Service', -0.034041095455175856]]
# Initial Explanation 2
#  [['Project Cost', 0.05478823217431454], ['School State_Mississippi', 0.03730139063149636], ['Project Resource Category_Technology', 0.023690645516198858], ['School City Success Rate', 0.011095313198366057]]
# After Compact Explanation 1
#  [['Project Cost', 0.056724531967839026], ['School State', -0.0357473257516693], ['Project Subject Subcategory Tree', -0.03484823039539686], ['Project Type', -0.024612928001115777]]
# After Compact Explanation 2
#  [['Project Cost', 0.05478823217431454], ['School State', 0.03730139063149636], ['Project Resource Category', 0.023690645516198858], ['School City Success Rate', 0.011095313198366057]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.5, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 29e0a29d76fc6cb4b14aeb322a591cb2***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05834088702531024], ['School State_New Mexico', -0.03702262135721661], ['School State_Nebraska', -0.035778810739517546], ['School State_Oregon', 0.033179612990335484]]
# Initial Explanation 2
#  [['Project Cost', 0.042972575324452006], ['Project Resource Category_Technology', 0.02089319688295632], ['Teacher Project Posted Sequence', 0.01729994020708773], ['School State_New Jersey', 0.014929176103460123]]
# After Compact Explanation 1
#  [['Project Cost', 0.05834088702531024], ['School State', -0.03702262135721661], ['Project Type', -0.03256394932923683], ['Project Subject Subcategory Tree', 0.026097074606813053]]
# After Compact Explanation 2
#  [['Project Cost', 0.042972575324452006], ['Project Resource Category', 0.02089319688295632], ['Teacher Project Posted Sequence', 0.01729994020708773], ['School State', 0.014929176103460123]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.25, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 2aef3f0d5d3dceb281d733ac66a960c2***********************************
# Initial Explanation 1
#  [['Project Subject Subcategory Tree_Civics & Government, Health & Life Science', -0.042944314863684864], ['Project Subject Subcategory Tree_College & Career Prep, Health & Wellness', -0.039735322027768555], ['Project Subject Subcategory Tree_Community Service, Social Sciences', -0.037199576352393265], ['Project Subject Subcategory Tree_Civics & Government, Music', -0.03715217560467798]]
# Initial Explanation 2
#  [['School State_Nebraska', 0.03591474745319829], ['Teacher Project Posted Sequence', 0.018754400938707932], ['Project Cost', 0.017606946816849812], ['School Success Rate', 0.016643644093455805]]
# After Compact Explanation 1
#  [['Project Subject Subcategory Tree', -0.042944314863684864], ['School State', -0.03572503387452157], ['Project Subject Category Tree', 0.033440799618520194], ['Project Resource Category', 0.023055042995004518]]
# After Compact Explanation 2
#  [['School State', 0.03591474745319829], ['Teacher Project Posted Sequence', 0.018754400938707932], ['Project Cost', 0.017606946816849812], ['School Success Rate', 0.016643644093455805]]
# Disagreement :  {'feature_agreement': 0.25, 'rank_agreement': 0.0, 'sign_agreement': 0.0, 'signed_rank_agreement': 0.0}
# ********************************************************************
# *********************************Project ID: ba886cbb122a2b426e8179a52992deb4***********************************
# Initial Explanation 1
#  [['Project Cost', 0.056703794419934485], ['School State_New Mexico', -0.03666939555168404], ['School State_Mississippi', -0.0326413983890403], ['Project Subject Subcategory Tree_ESL, Environmental Science', -0.032189349473148984]]
# Initial Explanation 2
#  [['Project Cost', 0.04900240726979064], ['Project Resource Category_Technology', 0.020153728891748414], ['Teacher Project Posted Sequence', 0.01675694361054411], ['School Success Rate', 0.014765536128286384]]
# After Compact Explanation 1
#  [['Project Cost', 0.056703794419934485], ['School State', -0.03666939555168404], ['Project Subject Subcategory Tree', -0.032189349473148984], ['Project Resource Category', 0.024613314729921787]]
# After Compact Explanation 2
#  [['Project Cost', 0.04900240726979064], ['Project Resource Category', 0.020153728891748414], ['Teacher Project Posted Sequence', 0.01675694361054411], ['School Success Rate', 0.014765536128286384]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.25, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: e88b4aa68d80c8f80216ffc9195094d3***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05727184893446674], ['School State_Mississippi', -0.034829925907879686], ['School State_Oregon', 0.033932449298387866], ['School State_New Mexico', -0.033260291558436225]]
# Initial Explanation 2
#  [['Project Cost', 0.0533763027604391], ['Project Resource Category_Technology', 0.02020581985175113], ['Teacher Project Posted Sequence', 0.0166598387324575], ['School Success Rate', 0.014527601223701368]]
# After Compact Explanation 1
#  [['Project Cost', 0.05727184893446674], ['School State', -0.034829925907879686], ['Project Subject Subcategory Tree', -0.031873226195514685], ['Project Resource Category', 0.024871330403812366]]
# After Compact Explanation 2
#  [['Project Cost', 0.0533763027604391], ['Project Resource Category', 0.02020581985175113], ['Teacher Project Posted Sequence', 0.0166598387324575], ['School Success Rate', 0.014527601223701368]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.25, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 32f762ac688dab9e805913d36475cc5c***********************************
# Initial Explanation 1
#  [['Project Cost', 0.057725804649885123], ['School State_New Mexico', -0.03907529194402031], ['School State_Mississippi', -0.039006967290825825], ['Project Subject Subcategory Tree_Mathematics, Performing Arts', 0.03477392829071952]]
# Initial Explanation 2
#  [['Project Cost', 0.051042751218146803], ['Project Resource Category_Technology', 0.01945403043239139], ['Teacher Project Posted Sequence', 0.016914294512507696], ['School Success Rate', 0.01594168940754571]]
# After Compact Explanation 1
#  [['Project Cost', 0.057725804649885123], ['School State', -0.03907529194402031], ['Project Subject Subcategory Tree', 0.03477392829071952], ['Project Resource Category', 0.02417584917028358]]
# After Compact Explanation 2
#  [['Project Cost', 0.051042751218146803], ['Project Resource Category', 0.01945403043239139], ['Teacher Project Posted Sequence', 0.016914294512507696], ['School Success Rate', 0.01594168940754571]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.25, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: b44d5a076635192baef2dc41af4e3925***********************************
# Initial Explanation 1
#  [['Project Cost', 0.057756968315744825], ['School State_New Mexico', -0.03932150266993941], ['School State_Nebraska', -0.03667133368483777], ['School State_Mississippi', -0.03368040296492842]]
# Initial Explanation 2
#  [['Project Cost', 0.048827031038917994], ['Project Resource Category_Technology', 0.01990386318623166], ['School State_Nevada', 0.017167976901582734], ['Teacher Project Posted Sequence', 0.016864384248160603]]
# After Compact Explanation 1
#  [['Project Cost', 0.057756968315744825], ['School State', -0.03932150266993941], ['Project Subject Subcategory Tree', -0.03171387138876598], ['Project Resource Category', 0.023225583351749825]]
# After Compact Explanation 2
#  [['Project Cost', 0.048827031038917994], ['Project Resource Category', 0.01990386318623166], ['School State', 0.017167976901582734], ['Teacher Project Posted Sequence', 0.016864384248160603]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.25, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: a5aeadf440571a7f9c8f8006e4dfefd7***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05730394979700184], ['Project Subject Subcategory Tree_Applied Sciences, Nutrition Education', -0.03548513949962272], ['School State_Oregon', 0.03288513294946944], ['School State_Mississippi', -0.03274520841377332]]
# Initial Explanation 2
#  [['Project Cost', 0.048074601439780054], ['Project Resource Category_Technology', 0.02183347429010041], ['Teacher Project Posted Sequence', 0.017279435080149598], ['School Success Rate', 0.014386887156513239]]
# After Compact Explanation 1
#  [['Project Cost', 0.05730394979700184], ['Project Subject Subcategory Tree', -0.03548513949962272], ['School State', 0.03288513294946944], ['Project Resource Category', 0.02330414951622436]]
# After Compact Explanation 2
#  [['Project Cost', 0.048074601439780054], ['Project Resource Category', 0.02183347429010041], ['Teacher Project Posted Sequence', 0.017279435080149598], ['School Success Rate', 0.014386887156513239]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.25, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 79777c5022ab41f9c2d14e669d6e9848***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05711075916584293], ['School State_New Mexico', -0.05007291483298276], ['School State_Mississippi', 0.03441870219039733], ['Project Subject Subcategory Tree_Civics & Government, Economics', -0.03387718601732553]]
# Initial Explanation 2
#  [['Project Cost', 0.0499966510051263], ['School State_Mississippi', 0.04133924439976908], ['Project Resource Category_Technology', 0.02435748696833059], ['School Success Rate', 0.013009365193852318]]
# After Compact Explanation 1
#  [['Project Cost', 0.05711075916584293], ['School State', -0.05007291483298276], ['Project Subject Subcategory Tree', -0.03387718601732553], ['Project Type', -0.028144756591672652]]
# After Compact Explanation 2
#  [['Project Cost', 0.0499966510051263], ['School State', 0.04133924439976908], ['Project Resource Category', 0.02435748696833059], ['School Success Rate', 0.013009365193852318]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.5, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 91da7041354b1ae9bd7e333019ec67e5***********************************
# Initial Explanation 1
#  [['Project Cost', 0.05792435137899319], ['School State_New Mexico', -0.03471500427769043], ['School State_Oregon', 0.03280479112032359], ['Project Subject Subcategory Tree_Extracurricular, Health & Wellness', -0.032423247175645896]]
# Initial Explanation 2
#  [['Project Cost', 0.049578029367235106], ['Project Resource Category_Technology', 0.020179474893102452], ['Teacher Project Posted Sequence', 0.017520207738989484], ['School Success Rate', 0.015746680620977713]]
# After Compact Explanation 1
#  [['Project Cost', 0.05792435137899319], ['School State', -0.03471500427769043], ['Project Subject Subcategory Tree', -0.032423247175645896], ['Project Type', -0.025411231121089433]]
# After Compact Explanation 2
#  [['Project Cost', 0.049578029367235106], ['Project Resource Category', 0.020179474893102452], ['Teacher Project Posted Sequence', 0.017520207738989484], ['School Success Rate', 0.015746680620977713]]
# Disagreement :  {'feature_agreement': 0.25, 'rank_agreement': 0.25, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ...
# Initial Explanation 2
#  [['School State_Pennsylvania', -0.024817858588303352], ['School Success Rate', -0.019576381572719584], ['Project Cost', -0.019522912182696927], ['Project Resource Category_Books', -0.01777852292710918]]
# After Compact Explanation 1
#  [['Project Subject Subcategory Tree', -0.03573240761855758], ['School State', -0.03423442157747255], ['Project Cost', -0.029437997339595928], ['Project Type', -0.02754671495081698]]
# After Compact Explanation 2
#  [['School State', -0.024817858588303352], ['School Success Rate', -0.019576381572719584], ['Project Cost', -0.019522912182696927], ['Project Resource Category', -0.01777852292710918]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.25, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 47ce14f4a21db0bcba47dff7e0a046e0***********************************
# Initial Explanation 1
#  [['Project Cost', -0.0403338967990037], ['School State_Nebraska', -0.0382654783366614], ['School State_New Mexico', -0.03743744311834552], ['School State_Mississippi', -0.03412689799690936]]
# Initial Explanation 2
#  [['Project Cost', -0.023865439897460875], ['School Success Rate', -0.01876499327177271], ['Project Resource Category_Books', -0.017454083456228203], ['School State_Virginia', -0.016763172180412768]]
# After Compact Explanation 1
#  [['Project Cost', -0.0403338967990037], ['School State', -0.0382654783366614], ['Project Subject Subcategory Tree', -0.032531277929992664], ['Project Type', -0.02940476504364735]]
# After Compact Explanation 2
#  [['Project Cost', -0.023865439897460875], ['School Success Rate', -0.01876499327177271], ['Project Resource Category', -0.017454083456228203], ['School State', -0.016763172180412768]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.25, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 83cffecbc0ab000c124a913ac6d984d4***********************************
# Initial Explanation 1
#  [['Project Cost', -0.03950630038803691], ['School State_New Mexico', -0.037857172792252536], ['Project Subject Subcategory Tree_College & Career Prep, Nutrition Education', -0.036450119190606804], ['Project Subject Subcategory Tree_Extracurricular, Nutrition Education', -0.03535268302201976]]
# Initial Explanation 2
#  [['Project Cost', -0.023336376928518802], ['School Success Rate', -0.019367315043552935], ['Project Resource Category_Books', -0.015577970405397537], ['School State_Illinois', -0.015041787255590862]]
# After Compact Explanation 1
#  [['Project Cost', -0.03950630038803691], ['School State', -0.037857172792252536], ['Project Subject Subcategory Tree', -0.036450119190606804], ['Project Type', -0.02711729907783503]]
# After Compact Explanation 2
#  [['Project Cost', -0.023336376928518802], ['School Success Rate', -0.019367315043552935], ['Project Resource Category', -0.015577970405397537], ['School State', -0.015041787255590862]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.25, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 79579a6a858ea5d559c827e61613cd54***********************************
# Initial Explanation 1
#  [['Project Cost', -0.03917749227225276], ['Project Subject Subcategory Tree_College & Career Prep, Other', -0.03373761000069512], ['Project Subject Category Tree_Health & Sports, Math & Science', 0.03354001743493054], ['School State_New Mexico', -0.031816362931115255]]
# Initial Explanation 2
#  [['School State_Pennsylvania', -0.023265148259674788], ['Project Cost', -0.02265036555696497], ['School Success Rate', -0.018811087389212843], ['Project Resource Category_Books', -0.016703273829004387]]
# After Compact Explanation 1
#  [['Project Cost', -0.03917749227225276], ['Project Subject Subcategory Tree', -0.03373761000069512], ['Project Subject Category Tree', 0.03354001743493054], ['School State', -0.031816362931115255]]
# After Compact Explanation 2
#  [['School State', -0.023265148259674788], ['Project Cost', -0.02265036555696497], ['School Success Rate', -0.018811087389212843], ['Project Resource Category', -0.016703273829004387]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.0, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.0}
# ********************************************************************
# *********************************Project ID: b9bf6a8d716da1490455f505f8b85007***********************************
# Initial Explanation 1
#  [['School State_Mississippi', -0.04107184862313919], ['Project Cost', -0.03861352976636788], ['School State_New Mexico', -0.034256737665752254], ['School State_Montana', 0.02932699247111329]]
# Initial Explanation 2
#  [['School State_Pennsylvania', -0.024472313645483156], ['Project Cost', -0.020407086301020172], ['School Success Rate', -0.01854667662519432], ['Project Resource Category_Books', -0.015849915274194472]]
# After Compact Explanation 1
#  [['School State', -0.04107184862313919], ['Project Cost', -0.03861352976636788], ['Project Subject Subcategory Tree', -0.028425301321594786], ['School Success Rate', -0.026660263798136012]]
# After Compact Explanation 2
#  [['School State', -0.024472313645483156], ['Project Cost', -0.020407086301020172], ['School Success Rate', -0.01854667662519432], ['Project Resource Category', -0.015849915274194472]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.5, 'sign_agreement': 0.75, 'signed_rank_agreement': 0.5}
# ********************************************************************
# *********************************Project ID: 6707d874f4a72e400ae089d399388801***********************************
# Initial Explanation 1
#  [['Project Cost', -0.039475249400354476], ['Project Subject Subcategory Tree_Character Education, Community Service', -0.037255604946065765], ['School State_Oregon', 0.03627432838850664], ['School State_Mississippi', -0.0329036378718214]]
# Initial Explanation 2
#  [['Project Cost', -0.024379223802133084], ['School State_Pennsylvania', -0.0240622144181566], ['Project Resource Category_Books', -0.015314621352885638], ['Teacher Success Rate', -0.013575487261293801]]
# After Compact Explanation 1
#  [['Project Cost', -0.039475249400354476], ['Project Subject Subcategory Tree', -0.037255604946065765], ['School State', 0.03627432838850664], ['Project Subject Category Tree', -0.02708778837514192]]
# After Compact Explanation 2
#  [['Project Cost', -0.024379223802133084], ['School State', -0.0240622144181566], ['Project Resource Category', -0.015314621352885638], ['Teacher Success Rate', -0.013575487261293801]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.25, 'sign_agreement': 0.25, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: da5a839e2fb3090457cbe77cb8d2bf3c***********************************
# Initial Explanation 1
#  [['School State_Mississippi', -0.04216019747286353], ['School State_New Mexico', -0.03940831536015678], ['Project Subject Subcategory Tree_Extracurricular, Health & Wellness', -0.038033968843669747], ['Project Subject Subcategory Tree_Civics & Government, Literature & Writing', -0.03551151077873311]]
# Initial Explanation 2
#  [['School State_Pennsylvania', -0.024094042611991426], ['School Success Rate', -0.018976930578592146], ['Project Cost', -0.01762455067711812], ['Project Resource Category_Books', -0.016992284252175978]]
# After Compact Explanation 1
#  [['School State', -0.04216019747286353], ['Project Subject Subcategory Tree', -0.038033968843669747], ['Project Cost', -0.02813253927781302], ['School Success Rate', -0.02729983257875776]]
# After Compact Explanation 2
#  [['School State', -0.024094042611991426], ['School Success Rate', -0.018976930578592146], ['Project Cost', -0.01762455067711812], ['Project Resource Category', -0.016992284252175978]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.5, 'sign_agreement': 0.75, 'signed_rank_agreement': 0.5}
# ********************************************************************
# *********************************Project ID: 00df73eae4c7676532afd4fd247eeaf5***********************************
# Initial Explanation 1
#  [['School State_New Mexico', -0.038328677363711684], ['Project Subject Subcategory Tree_Parent Involvement', -0.03687262335341002], ['Project Subject Subcategory Tree_Gym & Fitness, Literacy', -0.03316394664036977], ['School State_Oregon', 0.03089119369649633]]
# Initial Explanation 2
#  [['School State_Pennsylvania', -0.023266224538965617], ['School Success Rate', -0.019976985419846188], ['Project Resource Category_Books', -0.017940978202442465], ['Project Cost', -0.016809361386485762]]
# After Compact Explanation 1
#  [['School State', -0.038328677363711684], ['Project Subject Subcategory Tree', -0.03687262335341002], ['Project Cost', -0.028300317208831298], ['School Success Rate', -0.027540061738850576]]
# After Compact Explanation 2
#  [['School State', -0.023266224538965617], ['School Success Rate', -0.019976985419846188], ['Project Resource Category', -0.017940978202442465], ['Project Cost', -0.016809361386485762]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.25, 'sign_agreement': 0.75, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 0bdb95917952677fb36c96958f54ac12***********************************
# Initial Explanation 1
#  [['Project Cost', -0.03969984803424104], ['School State_Mississippi', -0.035581411783628836], ['School State_Oregon', 0.035345508586937746], ['Project Subject Subcategory Tree_Economics, Literature & Writing', 0.034732279874778574]]
# Initial Explanation 2
#  [['Project Cost', -0.023331152635100806], ['School State_Pennsylvania', -0.022117249078000896], ['School Success Rate', -0.019433458189300836], ['Project Resource Category_Books', -0.017247402750348896]]
# After Compact Explanation 1
#  [['Project Cost', -0.03969984803424104], ['School State', -0.035581411783628836], ['Project Subject Subcategory Tree', 0.034732279874778574], ['School Success Rate', -0.026031417196338513]]
# After Compact Explanation 2
#  [['Project Cost', -0.023331152635100806], ['School State', -0.022117249078000896], ['School Success Rate', -0.019433458189300836], ['Project Resource Category', -0.017247402750348896]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.5, 'sign_agreement': 0.75, 'signed_rank_agreement': 0.5}
# ********************************************************************
# *********************************Project ID: 887a077ba42d45e0dc05c240f0af0633***********************************
# Initial Explanation 1
#  [['Project Cost', -0.04021791014326399], ['School State_Oregon', 0.034984319995813494], ['School State_New Mexico', -0.0327969262104795], ['School State_Mississippi', -0.03139561774011325]]
# Initial Explanation 2
#  [['School State_Pennsylvania', -0.024083022744432584], ['Project Cost', -0.02396973068960392], ['Project Resource Category_Books', -0.016001645903421034], ['School Success Rate', -0.014267826921818596]]
# After Compact Explanation 1
#  [['Project Cost', -0.04021791014326399], ['School State', 0.034984319995813494], ['Project Subject Subcategory Tree', -0.031393948535020914], ['Project Resource Category', -0.025756515708827882]]
# After Compact Explanation 2
#  [['School State', -0.024083022744432584], ['Project Cost', -0.02396973068960392], ['Project Resource Category', -0.016001645903421034], ['School Success Rate', -0.014267826921818596]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.0, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.0}
# ********************************************************************
# *********************************Project ID: b4d146a45c4138ef19687f3b1d173bd3***********************************
# Initial Explanation 1
#  [['Project Subject Subcategory Tree_Nutrition Education', 0.04417017003105334], ['School State_New Mexico', -0.04266039540464139], ['School State_Nebraska', -0.04153330496518257], ['Project Subject Subcategory Tree_ESL, Performing Arts', 0.04013310684404135]]
# Initial Explanation 2
#  [['School State_Pennsylvania', -0.02248809102557061], ['School Success Rate', -0.0192491933155884], ['Project Resource Category_Books', -0.01834598207045019], ['Project Cost', -0.0153705713457407]]
# After Compact Explanation 1
#  [['Project Subject Subcategory Tree', 0.04417017003105334], ['School State', -0.04266039540464139], ['Project Cost', -0.029483049627122736], ['Project Type', -0.027702893869299312]]
# After Compact Explanation 2
#  [['School State', -0.02248809102557061], ['School Success Rate', -0.0192491933155884], ['Project Resource Category', -0.01834598207045019], ['Project Cost', -0.0153705713457407]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.0, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.0}
# ********************************************************************
# *********************************Project ID: 6702b7abec726b747510b511f3748202***********************************
# Initial Explanation 1
#  [['Project Subject Subcategory Tree_Health & Wellness, Social Sciences', -0.039857360749737496], ['Project Cost', -0.03937617123424127], ['Project Subject Subcategory Tree_Extracurricular, Literature & Writing', -0.03741575438299199], ['School State_Oregon', 0.037368429436861715]]
# Initial Explanation 2
#  [['School State_Pennsylvania', -0.023714219267644693], ['Project Cost', -0.02264040245009937], ['School Success Rate', -0.01895342324730791], ['Project Resource Category_Books', -0.018567483294975203]]
# After Compact Explanation 1
#  [['Project Subject Subcategory Tree', -0.039857360749737496], ['Project Cost', -0.03937617123424127], ['School State', 0.037368429436861715], ['School Success Rate', -0.027243885064380007]]
# After Compact Explanation 2
#  [['School State', -0.023714219267644693], ['Project Cost', -0.02264040245009937], ['School Success Rate', -0.01895342324730791], ['Project Resource Category', -0.018567483294975203]]
# Disagreement :  {'feature_agreement': 0.75, 'rank_agreement': 0.25, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.25}
# ********************************************************************
# *********************************Project ID: 4b42bfd3856952f9d8acf54f2e162376***********************************
# Initial Explanation 1
#  [['Project Cost', -0.040752820574125964], ['Project Subject Subcategory Tree_History & Geography, Other', -0.03742279253644754], ['School State_New Mexico', -0.03473091383138168], ['Project Subject Subcategory Tree_Early Development, Health & Life Science', 0.033446237556612635]]
# Initial Explanation 2
#  [['School State_Pennsylvania', -0.023587470788988867], ['Project Cost', -0.02346245084651855], ['School Success Rate', -0.018711507567977605], ['Project Resource Category_Books', -0.017750042706492764]]
# After Compact Explanation 1
#  [['Project Cost', -0.040752820574125964], ['Project Subject Subcategory Tree', -0.03742279253644754], ['School State', -0.03473091383138168], ['Project Type', -0.02935017879206173]]
# After Compact Explanation 2
#  [['School State', -0.023587470788988867], ['Project Cost', -0.02346245084651855], ['School Success Rate', -0.018711507567977605], ['Project Resource Category', -0.017750042706492764]]
# Disagreement :  {'feature_agreement': 0.5, 'rank_agreement': 0.0, 'sign_agreement': 0.5, 'signed_rank_agreement': 0.0}
# ********************************************************************
# ********************************************************************
# {'feature_agreement': 0.512, 'rank_agreement': 0.158, 'sign_agreement': 0.497, 'signed_rank_agreement': 0.152}
# ********************************************************************

# %%
print(top)
# Out:
# {'feature_agreement': 0.438, 'rank_agreement': 0.264, 'sign_agreement': 0.34, 'signed_rank_agreement': 0.237}

# %%
print(bottom)
# Out:
# {'feature_agreement': 0.512, 'rank_agreement': 0.158, 'sign_agreement': 0.497, 'signed_rank_agreement': 0.152}
